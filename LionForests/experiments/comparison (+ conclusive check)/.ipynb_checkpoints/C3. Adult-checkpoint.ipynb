# %% [markdown]
# # This notebook contains the experiments on Adult Census dataset with LionForests

# %%
import sys
cpath = !pwd
sys.path.append(cpath[0][:-43]) 
sys.path.append(cpath[0][:-43]+'/algorithms')

# %%
from lionforests import LionForests
from algorithms.simpleSurrogate import GlobalSurrogateTree, LocalSurrogateTree
from algorithms.DefragTrees.defragTrees import DefragModel
from CHIRPS.structures import data_container
import CHIRPS.routines as rt
import CHIRPS.structures as strcts

from scipy import sparse

from datasets.dataset import Dataset
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pandas as pd 
import numpy as np
np.seterr(invalid='ignore')
import warnings
warnings.filterwarnings("ignore")
import time

from sklearn.model_selection import train_test_split, LeaveOneOut
from sklearn.metrics import f1_score, precision_score

from anchor import anchor_tabular

# %% [markdown]
# Feature Engineering from:
# https://github.com/pooja2512/Adult-Census-Income/blob/master/Adult%20Census%20Income.ipynb. So run and skip the next code block

# %%
adult = Dataset()
X, y, feature_names, class_names, categorical_features = adult.load_adult()
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1000, stratify=y, random_state=random_s)
#X = X_test
#y = y_test
y = np.array(y)

# %%
#one_h_percent = int(min(10*len(X)/100,100))
#print("Instances:",one_h_percent)
new_fn = []
for i in feature_names:
    new_fn.append(i.replace(' ','_'))
feature_names = new_fn

# %%
def measure(X_train, X_test, y_train, y_test, feature_names, class_names):
    parameters = [{
        'max_depth': [5],
        'max_features': [0.75],
        'bootstrap': [True],
        'min_samples_leaf' : [2],
        'n_estimators': [500]
    }]
    scaler = MinMaxScaler(feature_range=(-1,1))
    lf = LionForests(None, False, scaler, feature_names, class_names)#, categorical_features)
    lf.fit(X_train, y_train, params=parameters)
    
    train = lf.utilizer.transform(X_train)
    test = lf.utilizer.transform(X_test)

    predictions = lf.model.predict(train)
    test_predictions = lf.model.predict(test)
    
    def techniques(model, train, y_train, predictions, test, feature_names, class_names, lf, task):

        #LionForests
        def lf_rule(instance):
            temp = lf.explain(instance, reduction=True, ar_algorithm='fpgrowth', cl_algorithm='kmedoids', method='123')[-1]
            rule = {}
            for key,value in temp.items():
                rule[key] = [['<=',value[1]],['>',value[0]]]
            return rule
        print('    LF Ready')
        #BaselineTechnique ==============================================================================
        gt = GlobalSurrogateTree(train, predictions, feature_names, task)
        print('    GT Ready')
        lt = LocalSurrogateTree(train, predictions, feature_names, task, 150)
        print('    LT Ready')
        #DefragTechnique ================================================================================
        Kmax = 10
        splitter = DefragModel.parseSLtrees(model) # parse sklearn tree ensembles into the array of (feature index, threshold)
        mdl = DefragModel(modeltype=task, maxitr=10, qitr=0, tol=1e-6, restart=2, verbose=0)
        mdl.fit(train, predictions, splitter, Kmax, fittype='FAB', featurename=feature_names)
        def def_cov(instances):
            ts = time.time()
            score, cover, coll = mdl.evaluate(instances[1:],lf.model.predict(instances[1:]))
            def_predictions = mdl.predict(instances[1:])
            rule = mdl.find_rule_length(instances[0])
            return rule, cover, def_predictions, time.time() - ts
        print('    Defrag Ready')

        #Anchors =======================================================================================
        explainer = anchor_tabular.AnchorTabularExplainer(class_names, feature_names, train)
        def anchors_method(instance):
            exp = explainer.explain_instance(instance, lf.model.predict, threshold=0.95)
            anchors_dict = {}
            for i in exp.names():
                terms = i.split(' ')
                if len(terms) == 3:
                    anchors_dict[terms[0]] = [[terms[1],float(terms[2])]]
                else:
                    anchors_dict[terms[2]] = [[terms[3],float(terms[4])],[terms[1],float(terms[0])]]
            return anchors_dict, 0
        print('    Anchors Ready')
        
        #CHIRPS =======================================================================================
        project_dir = cpath[0][:-43]+'/algorithms/CHIRPS'
        temp_frame = pd.DataFrame(np.hstack((train,y_train.reshape(len(y_train),1))),columns=feature_names+['class'])
        temp_frame['class']=temp_frame['class'].astype(int)

        temp_frame = temp_frame.replace({"class": {1: 2}})
        temp_frame = temp_frame.replace({"class": {0: 1}})

        mydata = data_container(
                data = temp_frame, class_col = 'class', var_names = feature_names,
                project_dir = project_dir, save_dir = 'adult', random_state=123)
        meta_data = mydata.get_meta()
        f_walker = strcts.classification_trees_walker(forest=model, meta_data=meta_data)
        f_walker.forest_walk(instances = test, labels = model.predict(test), forest_walk_async = True)

        explanations = strcts.CHIRPS_container(f_walker.path_detail,
                                        forest=model,
                                        sample_instances=sparse.csr_matrix(train), # any representative sample can be used
                                        sample_labels=predictions,
                                        meta_data=meta_data)
        chts = time.time()
        explanations.run_explanations(target_classes=model.predict(test), # we're explaining the prediction, not the true label!
                                explanation_async=False,
                                random_state=123,
                                which_trees='majority',
                                alpha_paths=0.0,
                                support_paths=0.1,
                                score_func=1,
                                precis_threshold=0.99,
                                disc_path_bins=4,
                                merging_bootstraps=20,
                                pruning_bootstraps=20,
                                delta=0.2,
                                weighting='kldiv')
        chte = (time.time() - chts)/len(test)
        def chirps_method(idx):
            chirps_dict = {}
            for i in explanations.explainers[idx].pruned_rule:
                if i[1]:
                    chirps_dict[i[0]] = [['<=',float(i[2])]]
                else:
                    chirps_dict[i[0]] = [['>',float(i[2])]]
            return chirps_dict, 0, chte
        print('    CHIRPS Ready')
        return {'gs':gt.rule,'ls':lt.rule,'an':anchors_method,'lf':lf_rule, 'df': def_cov, 'ch':chirps_method}
        #return {'lf':lf_rule}
    interpretation = techniques(lf.model, train, y_train, predictions, test, feature_names, class_names, lf, 'classification')
    def rule_cov(instance, feature_names, rule):
        covered = True
        for k in range(len(instance)):
            feature = feature_names[k]
            if feature in rule.keys():
                if len(rule[feature]) == 2:
                    if instance[k] > rule[feature][0][1]: #<=
                        return 0
                    if instance[k] <= rule[feature][1][1]:#THIS <=
                        #covered = False
                        return 0
                elif rule[feature][0][0] == '>':
                    if instance[k] <= rule[feature][0][1]:
                        #covered = False
                        return 0
                else:
                    if instance[k] > rule[feature][0][1]: #<=
                        #covered = False
                        return 0
        
        return 1
    def rule_cov_LF(instance, feature_names, rule):
        covered = True
        for k in range(len(instance)):
            feature = feature_names[k]
            if feature in rule.keys():
                if len(rule[feature]) == 2:
                    if instance[k] > rule[feature][0][1]: #<=
                        return 0
                    if instance[k] < rule[feature][1][1]:#THIS <=
                        return 0
                elif rule[feature][0][0] == '>':
                    if instance[k] <= rule[feature][0][1]:
                        return 0
                else:
                    if instance[k] > rule[feature][0][1]: #<=
                        return 0
        return 1
        #else:
        #    return 0
        
    #loo = LeaveOneOut()
    #loo.get_n_splits(test)
    rule_generator = interpretation
    full_coverage = {'gs':0, 'ls':0, 'an':0, 'lf':0, 'df':0, 'ch': 0}
    rule_length = {'gs':0, 'ls':0, 'an':0, 'lf':0, 'df':0, 'ch': 0}
    f_precision = {'gs':[], 'ls':[], 'an':[], 'lf':[], 'df':[], 'ch':[]}
    time_response = {'gs':[], 'ls':[], 'an':[], 'lf':[], 'df':[], 'ch':[]}
    #full_coverage = {'lf':0}
    #rule_length = {'lf':0}
    #f_precision = {'lf':[]}
    #time_response = {'lf':[]}
    
    x_train_temp = train
    x_test_temp = test

    y_train_temp = predictions
    y_test_temp = test_predictions
    
    x_train_temp_lf = lf.utilizer.inverse_transform(x_train_temp)
    x_test_temp_lf = lf.utilizer.inverse_transform(x_test_temp)    
    ktime = time.time()
    for test_ind in range(len(test)):
        if test_ind % 100 ==0:
            print(round(test_ind/(len(test))*100,2),'in:', time.time()-ktime)
            ktime = time.time()
            import pickle
            with open('parrot.pkl', 'wb') as f:
                pickle.dump([full_coverage, rule_length, f_precision, time_response], f)
        for name, method in rule_generator.items():
            if name == 'ch':
                rule, op, te = method(test_ind)
                coverage = 0
                precision = []
                co = 0
                for i in x_test_temp:
                    res = rule_cov(i, feature_names, rule)
                    coverage = coverage + res
                    if res == 1:
                        precision.append([y_test_temp[test_ind], y_test_temp[co]])
                    co = co + 1
                if len(precision) >= 1:
                    precision = np.array(precision)
                    f_precision[name].append(precision_score(precision[:,:1],precision[:,1:],average='micro'))
                full_coverage[name] = full_coverage[name] + coverage/len(x_test_temp)
            elif name == 'df':
                #FIX RULE LENGTH!
                rule, cover, predictions, te = method(np.concatenate((x_test_temp[test_ind:test_ind+1],x_test_temp)))
                f_precision[name].append(precision_score(predictions,y_test_temp,average='micro'))
                full_coverage[name] = full_coverage[name] + cover
            elif name == 'lf':
                ts = time.time()
                rule = method(x_test_temp_lf[test_ind])
                te = time.time() - ts
                coverage = 0
                precision = []
                co = 0
                for i in x_test_temp_lf:
                    res = rule_cov_LF(i, feature_names, rule)
                    coverage = coverage + res
                    if res == 1:
                        precision.append([y_test_temp[test_ind], y_test_temp[co]])
                    co = co + 1
                if len(precision) >= 1:
                    precision = np.array(precision)
                    f_precision[name].append(precision_score(precision[:,:1],precision[:,1:],average='micro'))
                full_coverage[name] = full_coverage[name] + coverage/len(x_test_temp_lf)
            else:
                ts = time.time()
                rule, prediction = method(x_test_temp[test_ind])
                te = time.time() - ts
                coverage = 0
                precision = []
                co = 0 
                for i in x_test_temp:
                    if name == 'anchors':
                        res = rule_cov(i, feature_names, rule)
                    else:    
                        res = rule_cov(i, feature_names, rule)
                    coverage = coverage + res
                    if res == 1 and name=='anchors':
                        precision.append([y_test_temp[test_ind], y_test_temp[co]])
                    elif res == 1:
                        precision.append([prediction, y_test_temp[co]])
                    co = co + 1
                if len(precision) >= 1:
                    precision = np.array(precision)
                    f_precision[name].append(precision_score(precision[:,:1],precision[:,1:],average='micro'))
                full_coverage[name] = full_coverage[name] + coverage/len(x_test_temp)
            time_response[name].append(te)
            rule_length[name] = rule_length[name] + len(rule)
    return rule_generator, full_coverage, rule_length, f_precision, time_response

# %%
def print_current(total_results):
    full_coverage = {'gs':[], 'ls':[], 'an':[], 'lf':[], 'df':[], 'ch': []}
    rule_length = {'gs':[], 'ls':[], 'an':[], 'lf':[], 'df':[], 'ch': []}
    f_precision = {'gs':[], 'ls':[], 'an':[], 'lf':[], 'df':[], 'ch':[]}
    f_time = {'gs':[], 'ls':[], 'an':[], 'lf':[], 'df':[], 'ch':[]}

    for i in total_results:
        for name, method in i[0].items():
            full_coverage[name].append(i[1][name]/len(i[4][name]))
            rule_length[name].append(i[2][name]/len(i[4][name]))
            if len(i[3][name]) >= 1:
                f_precision[name].append(np.array(i[3][name]))                
            f_time[name].append(np.array(i[4][name]))
    for name, method in i[0].items():
        print(name,np.array(full_coverage[name]).mean(),',',
              np.array(rule_length[name]).mean(),',',
              np.array(f_precision[name]).mean(),',',
              np.array(f_time[name]).mean())

# %%
total_results = []
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=7)

# %%
results = measure(X_train, X_test[:1000], y_train, y_test[:1000], feature_names, class_names)
total_results.append(results)
total_results.append(results)
print_current(total_results)
# Out:
#     LF Ready
#     GT Ready
#     LT Ready
#     Defrag Ready
#     Anchors Ready
# len self.path_detail
# 1000
# Working on CHIRPS for instance 0 of 1000
# as_chirps for batch_idx 0
# start mining for batch_idx 0 with support = 0.1
# found 52 patterns from 500 trees for batch_idx 0
# start score sort for batch_idx 0 (52) patterns
# start merge rule for batch_idx 0 (52) patterns
# [('capital-gain', True, -0.898), ('education_HS-grad', False, -0.125), ('capital-loss', True, -0.17839)]
# 0.9998615342010524 0.3996568518928492 0.2037587942840725 0.20068858285206564
# merge complete for batch_idx 0 (52) patterns
# start get explainer for batch_idx 0
# as_chirps for batch_idx 1
# start mining for batch_idx 1 with support = 0.1
# found 50 patterns from 375 trees for batch_idx 1
# start score sort for batch_idx 1 (50) patterns
# start merge rule for batch_idx 1 (50) patterns
# [('capital-loss', False, -0.17597), ('capital-loss', True, -0.08655), ('marital-status_Married', False, -0.125)]
# 0.9924924924924925 0.01837313885764357 0.1700233749893551 0.17270548428027627
# merge complete for batch_idx 1 (50) patterns
# start get explainer for batch_idx 1
# as_chirps for batch_idx 2
# start mining for batch_idx 2 with support = 0.1
# found 52 patterns from 500 trees for batch_idx 2
# start score sort for batch_idx 2 (52) patterns
# start merge rule for batch_idx 2 (52) patterns
# [('capital-gain', True, -0.85816), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.10642399315008699 0.15125908399526786
# merge complete for batch_idx 2 (52) patterns
# start get explainer for batch_idx 2
# as_chirps for batch_idx 3
# start mining for batch_idx 3 with support = 0.1
# found 56 patterns from 451 trees for batch_idx 3
# start score sort for batch_idx 3 (56) patterns
# start merge rule for batch_idx 3 (56) patterns
# [('education_HS-grad', True, 0.0), ('marital-status_Married', False, -0.125), ('occupation_Exec-managerial', False, -0.125), ('education_Elementary-school', True, 0.0)]
# 0.9551310528653931 0.06202598646144015 0.3102888174619628 0.25840879689521357
# merge complete for batch_idx 3 (56) patterns
# start get explainer for batch_idx 3
# as_chirps for batch_idx 4
# start mining for batch_idx 4 with support = 0.1
# found 56 patterns from 499 trees for batch_idx 4
# start score sort for batch_idx 4 (56) patterns
# start merge rule for batch_idx 4 (56) patterns
# [('marital-status_Married', True, 0.0), ('capital-gain', True, -0.85832)]
# 0.9972468149427769 0.5089488501125855 0.10163821265807707 0.18696206566783552
# merge complete for batch_idx 4 (56) patterns
# start get explainer for batch_idx 4
# Working on CHIRPS for instance 5 of 1000
# as_chirps for batch_idx 5
# start mining for batch_idx 5 with support = 0.1
# found 52 patterns from 500 trees for batch_idx 5
# start score sort for batch_idx 5 (52) patterns
# start merge rule for batch_idx 5 (52) patterns
# [('capital-gain', True, -0.898), ('education_HS-grad', False, -0.125), ('capital-loss', True, -0.17836)]
# 0.9998615342010524 0.3996568518928492 0.2040850407674441 0.20133333333333325
# merge complete for batch_idx 5 (52) patterns
# start get explainer for batch_idx 5
# as_chirps for batch_idx 6
# start mining for batch_idx 6 with support = 0.1
# found 57 patterns from 348 trees for batch_idx 6
# start score sort for batch_idx 6 (57) patterns
# start merge rule for batch_idx 6 (57) patterns
# [('education_HS-grad', True, 0.0), ('marital-status_Married', False, -0.125), ('occupation_Exec-managerial', False, -0.125), ('education_Elementary-school', True, 0.0)]
# 0.9551310528653931 0.06202598646144015 0.2865034988311985 0.26915142346307247
# merge complete for batch_idx 6 (57) patterns
# start get explainer for batch_idx 6
# as_chirps for batch_idx 7
# start mining for batch_idx 7 with support = 0.1
# found 52 patterns from 500 trees for batch_idx 7
# start score sort for batch_idx 7 (52) patterns
# start merge rule for batch_idx 7 (52) patterns
# [('capital-gain', True, -0.85816), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.10658722029781884 0.15210740992522093
# merge complete for batch_idx 7 (52) patterns
# start get explainer for batch_idx 7
# as_chirps for batch_idx 8
# start mining for batch_idx 8 with support = 0.1
# found 61 patterns from 500 trees for batch_idx 8
# start score sort for batch_idx 8 (61) patterns
# start merge rule for batch_idx 8 (61) patterns
# [('capital-gain', True, -0.85808), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.09181389645563341 0.15646346178631265
# merge complete for batch_idx 8 (61) patterns
# start get explainer for batch_idx 8
# as_chirps for batch_idx 9
# start mining for batch_idx 9 with support = 0.1
# found 57 patterns from 351 trees for batch_idx 9
# start score sort for batch_idx 9 (57) patterns
# start merge rule for batch_idx 9 (57) patterns
# [('education_HS-grad', True, 0.0), ('marital-status_Married', False, -0.125), ('occupation_Exec-managerial', False, -0.125), ('education_Elementary-school', True, 0.0)]
# 0.9551310528653931 0.06202598646144015 0.2870023546479741 0.2697629812303055
# merge complete for batch_idx 9 (57) patterns
# start get explainer for batch_idx 9
# Working on CHIRPS for instance 10 of 1000
# as_chirps for batch_idx 10
# start mining for batch_idx 10 with support = 0.1
# found 52 patterns from 500 trees for batch_idx 10
# start score sort for batch_idx 10 (52) patterns
# start merge rule for batch_idx 10 (52) patterns
# [('capital-gain', True, -0.85816), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.10658722029781884 0.15210740992522093
# merge complete for batch_idx 10 (52) patterns
# start get explainer for batch_idx 10
# as_chirps for batch_idx 11
# start mining for batch_idx 11 with support = 0.1
# found 45 patterns from 500 trees for batch_idx 11
# start score sort for batch_idx 11 (45) patterns
# start merge rule for batch_idx 11 (45) patterns
# [('capital-gain', True, -0.85817), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.1126865531429401 0.21807720861172986
# merge complete for batch_idx 11 (45) patterns
# start get explainer for batch_idx 11
# as_chirps for batch_idx 12
# start mining for batch_idx 12 with support = 0.1
# found 48 patterns from 500 trees for batch_idx 12
# start score sort for batch_idx 12 (48) patterns
# start merge rule for batch_idx 12 (48) patterns
# [('capital-gain', True, -0.85817), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.13376812557108542 0.2272642737586015
# merge complete for batch_idx 12 (48) patterns
# start get explainer for batch_idx 12
# as_chirps for batch_idx 13
# start mining for batch_idx 13 with support = 0.1
# found 61 patterns from 500 trees for batch_idx 13
# start score sort for batch_idx 13 (61) patterns
# start merge rule for batch_idx 13 (61) patterns
# [('marital-status_Married', True, 0.0), ('capital-gain', True, -0.85809)]
# 0.9972468149427769 0.5089488501125855 0.0881139334634102 0.1552682611506141
# merge complete for batch_idx 13 (61) patterns
# start get explainer for batch_idx 13
# as_chirps for batch_idx 14
# start mining for batch_idx 14 with support = 0.1
# found 56 patterns from 500 trees for batch_idx 14
# start score sort for batch_idx 14 (56) patterns
# start merge rule for batch_idx 14 (56) patterns
# [('marital-status_Married', True, 0.0), ('capital-gain', True, -0.85834)]
# 0.9972468149427769 0.5089488501125855 0.19321328723675174 0.3144749551538568
# merge complete for batch_idx 14 (56) patterns
# start get explainer for batch_idx 14
# Working on CHIRPS for instance 15 of 1000
# as_chirps for batch_idx 15
# start mining for batch_idx 15 with support = 0.1
# found 56 patterns from 195 trees for batch_idx 15
# start score sort for batch_idx 15 (56) patterns
# start merge rule for batch_idx 15 (56) patterns
# [('capital-gain', True, -0.89798)]
# 0.8466057820952824 0.22949857819796488 0.07987006651868724 0.07737594617325483
# merge complete for batch_idx 15 (56) patterns
# start get explainer for batch_idx 15
# as_chirps for batch_idx 16
# start mining for batch_idx 16 with support = 0.1
# found 70 patterns from 171 trees for batch_idx 16
# start score sort for batch_idx 16 (70) patterns
# start merge rule for batch_idx 16 (70) patterns
# [('capital-gain', True, -0.89799), ('occupation_Prof-specialty', True, 0.0), ('occupation_Exec-managerial', True, 0.0), ('education_Bachelors', True, 0.0), ('education_Masters', True, 0.0), ('capital-loss', True, -0.15243)]
# 0.9997326322356401 0.6206022180137238 0.13262530592019328 0.15873512836568549
# merge complete for batch_idx 16 (70) patterns
# start get explainer for batch_idx 16
# as_chirps for batch_idx 17
# start mining for batch_idx 17 with support = 0.1
# found 49 patterns from 500 trees for batch_idx 17
# start score sort for batch_idx 17 (49) patterns
# start merge rule for batch_idx 17 (49) patterns
# [('capital-gain', True, -0.85817), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.10673419083690454 0.20831858407079648
# merge complete for batch_idx 17 (49) patterns
# start get explainer for batch_idx 17
# as_chirps for batch_idx 18
# start mining for batch_idx 18 with support = 0.1
# found 58 patterns from 494 trees for batch_idx 18
# start score sort for batch_idx 18 (58) patterns
# start merge rule for batch_idx 18 (58) patterns
# [('marital-status_Married', True, 0.0), ('capital-gain', True, -0.85836)]
# 0.9972468149427769 0.5089488501125855 0.11077974006838615 0.17524693205627057
# merge complete for batch_idx 18 (58) patterns
# start get explainer for batch_idx 18
# as_chirps for batch_idx 19
# start mining for batch_idx 19 with support = 0.1
# found 52 patterns from 500 trees for batch_idx 19
# start score sort for batch_idx 19 (52) patterns
# start merge rule for batch_idx 19 (52) patterns
# [('capital-gain', True, -0.898), ('education_HS-grad', False, -0.125), ('capital-loss', True, -0.17839)]
# 0.9998615342010524 0.3996568518928492 0.2037589693413706 0.20068858285206564
# merge complete for batch_idx 19 (52) patterns
# start get explainer for batch_idx 19
# Working on CHIRPS for instance 20 of 1000
# as_chirps for batch_idx 20
# start mining for batch_idx 20 with support = 0.1
# found 52 patterns from 500 trees for batch_idx 20
# start score sort for batch_idx 20 (52) patterns
# start merge rule for batch_idx 20 (52) patterns
# [('capital-gain', True, -0.85816), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.10658723676215101 0.15210740992522093
# merge complete for batch_idx 20 (52) patterns
# start get explainer for batch_idx 20
# as_chirps for batch_idx 21
# start mining for batch_idx 21 with support = 0.1
# found 65 patterns from 205 trees for batch_idx 21
# start score sort for batch_idx 21 (65) patterns
# start merge rule for batch_idx 21 (65) patterns
# [('capital-gain', True, -0.89799), ('education_Bachelors', True, 0.0), ('occupation_Exec-managerial', True, 0.0), ('occupation_Prof-specialty', True, 0.0)]
# 0.9803988995873453 0.6016715111555156 0.0530896877175858 0.05210772833723658
# merge complete for batch_idx 21 (65) patterns
# start get explainer for batch_idx 21
# as_chirps for batch_idx 22
# start mining for batch_idx 22 with support = 0.1
# found 65 patterns from 394 trees for batch_idx 22
# start score sort for batch_idx 22 (65) patterns
# start merge rule for batch_idx 22 (65) patterns
# [('education_HS-grad', True, 0.0), ('marital-status_Married', False, -0.125), ('education_Elementary-school', True, 0.0), ('occupation_Prof-specialty', False, -0.125), ('education_Some-college', True, 0.0)]
# 0.9905660377358491 0.05857576136051463 0.30034311642309697 0.2553284992309384
# merge complete for batch_idx 22 (65) patterns
# start get explainer for batch_idx 22
# as_chirps for batch_idx 23
# start mining for batch_idx 23 with support = 0.1
# found 63 patterns from 426 trees for batch_idx 23
# start score sort for batch_idx 23 (63) patterns
# start merge rule for batch_idx 23 (63) patterns
# [('education_Bachelors', False, -0.125), ('marital-status_Married', False, -0.125)]
# 0.9677215189873418 0.08709263263685976 0.12424233041743266 0.07331587717210193
# merge complete for batch_idx 23 (63) patterns
# start get explainer for batch_idx 23
# as_chirps for batch_idx 24
# start mining for batch_idx 24 with support = 0.1
# found 52 patterns from 500 trees for batch_idx 24
# start score sort for batch_idx 24 (52) patterns
# start merge rule for batch_idx 24 (52) patterns
# [('capital-gain', True, -0.85816), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.1065872435291279 0.15210740992522093
# merge complete for batch_idx 24 (52) patterns
# start get explainer for batch_idx 24
# Working on CHIRPS for instance 25 of 1000
# as_chirps for batch_idx 25
# start mining for batch_idx 25 with support = 0.1
# found 54 patterns from 500 trees for batch_idx 25
# start score sort for batch_idx 25 (54) patterns
# start merge rule for batch_idx 25 (54) patterns
# [('capital-gain', True, -0.898), ('education_HS-grad', False, -0.125), ('capital-loss', True, -0.17804)]
# 0.9998615342010524 0.3996568518928492 0.2043807458450258 0.22508591065292086
# merge complete for batch_idx 25 (54) patterns
# start get explainer for batch_idx 25
# as_chirps for batch_idx 26
# start mining for batch_idx 26 with support = 0.1
# found 52 patterns from 500 trees for batch_idx 26
# start score sort for batch_idx 26 (52) patterns
# start merge rule for batch_idx 26 (52) patterns
# [('capital-gain', True, -0.898), ('education_HS-grad', False, -0.125), ('capital-loss', True, -0.17839)]
# 0.9998615342010524 0.3996568518928492 0.20375884923646811 0.20068858285206564
# merge complete for batch_idx 26 (52) patterns
# start get explainer for batch_idx 26
# as_chirps for batch_idx 27
# start mining for batch_idx 27 with support = 0.1
# found 59 patterns from 500 trees for batch_idx 27
# start score sort for batch_idx 27 (59) patterns
# start merge rule for batch_idx 27 (59) patterns
# [('capital-gain', True, -0.898), ('education_HS-grad', False, -0.125), ('capital-loss', True, -0.17519)]
# 0.9998615342010524 0.3996568518928492 0.12284873436860613 0.16065431697540883
# merge complete for batch_idx 27 (59) patterns
# start get explainer for batch_idx 27
# as_chirps for batch_idx 28
# start mining for batch_idx 28 with support = 0.1
# reduced 2 patterns out of 42 by numeric redundancy
# found 40 patterns from 500 trees for batch_idx 28
# start score sort for batch_idx 28 (40) patterns
# start merge rule for batch_idx 28 (40) patterns
# [('capital-gain', False, -0.898)]
# 0.9544678429140581 0.048436727275775304 0.13406040887313697 0.2249957257650881
# merge complete for batch_idx 28 (40) patterns
# start get explainer for batch_idx 28
# as_chirps for batch_idx 29
# start mining for batch_idx 29 with support = 0.1
# found 77 patterns from 236 trees for batch_idx 29
# start score sort for batch_idx 29 (77) patterns
# start merge rule for batch_idx 29 (77) patterns
# [('capital-gain', True, -0.898), ('occupation_Exec-managerial', True, 0.0), ('occupation_Prof-specialty', True, 0.0), ('capital-loss', True, -0.17887)]
# 0.9526023043305523 0.5770919913755098 0.11372363961571594 0.12370925288519943
# merge complete for batch_idx 29 (77) patterns
# start get explainer for batch_idx 29
# Working on CHIRPS for instance 30 of 1000
# as_chirps for batch_idx 30
# start mining for batch_idx 30 with support = 0.1
# found 54 patterns from 500 trees for batch_idx 30
# start score sort for batch_idx 30 (54) patterns
# start merge rule for batch_idx 30 (54) patterns
# [('marital-status_Married', True, 0.0), ('capital-gain', True, -0.85834)]
# 0.9972468149427769 0.5089488501125855 0.19714950041690263 0.3199045480067379
# merge complete for batch_idx 30 (54) patterns
# start get explainer for batch_idx 30
# as_chirps for batch_idx 31
# start mining for batch_idx 31 with support = 0.1
# found 59 patterns from 500 trees for batch_idx 31
# start score sort for batch_idx 31 (59) patterns
# start merge rule for batch_idx 31 (59) patterns
# [('marital-status_Married', True, 0.0), ('capital-gain', True, -0.85834)]
# 0.9972468149427769 0.5089488501125855 0.09319590481498642 0.17178996911310496
# merge complete for batch_idx 31 (59) patterns
# start get explainer for batch_idx 31
# as_chirps for batch_idx 32
# start mining for batch_idx 32 with support = 0.1
# found 47 patterns from 450 trees for batch_idx 32
# start score sort for batch_idx 32 (47) patterns
# start merge rule for batch_idx 32 (47) patterns
# [('capital-gain', True, -0.898), ('education_HS-grad', False, -0.125), ('capital-loss', True, -0.17838)]
# 0.9998615342010524 0.3996568518928492 0.1974452078082518 0.2056041192671536
# merge complete for batch_idx 32 (47) patterns
# start get explainer for batch_idx 32
# as_chirps for batch_idx 33
# start mining for batch_idx 33 with support = 0.1
# found 75 patterns from 250 trees for batch_idx 33
# start score sort for batch_idx 33 (75) patterns
# start merge rule for batch_idx 33 (75) patterns
# [('capital-gain', True, -0.898), ('education_Elementary-school', True, 0.0), ('education_HS-grad', True, 0.0), ('education_Some-college', False, -0.125), ('occupation_Exec-managerial', True, 0.0), ('capital-loss', True, -0.17887)]
# 0.9924046787179097 0.1808594035275679 0.1820027765580174 0.1951026856240127
# merge complete for batch_idx 33 (75) patterns
# start get explainer for batch_idx 33
# as_chirps for batch_idx 34
# start mining for batch_idx 34 with support = 0.1
# found 59 patterns from 498 trees for batch_idx 34
# start score sort for batch_idx 34 (59) patterns
# start merge rule for batch_idx 34 (59) patterns
# [('marital-status_Married', True, 0.0), ('capital-gain', True, -0.85834)]
# 0.9972468149427769 0.5089488501125855 0.0933783215132974 0.17200823287268455
# merge complete for batch_idx 34 (59) patterns
# start get explainer for batch_idx 34
# Working on CHIRPS for instance 35 of 1000
# as_chirps for batch_idx 35
# start mining for batch_idx 35 with support = 0.1
# found 52 patterns from 500 trees for batch_idx 35
# start score sort for batch_idx 35 (52) patterns
# start merge rule for batch_idx 35 (52) patterns
# [('capital-gain', True, -0.85816), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.10642401963986439 0.15125908399526786
# merge complete for batch_idx 35 (52) patterns
# start get explainer for batch_idx 35
# as_chirps for batch_idx 36
# start mining for batch_idx 36 with support = 0.1
# found 66 patterns from 453 trees for batch_idx 36
# start score sort for batch_idx 36 (66) patterns
# start merge rule for batch_idx 36 (66) patterns
# [('education_HS-grad', True, 0.0), ('marital-status_Married', False, -0.125), ('education_Bachelors', False, -0.125)]
# 0.9677215189873418 0.08709263263685976 0.21525889624856281 0.17004991680532439
# merge complete for batch_idx 36 (66) patterns
# start get explainer for batch_idx 36
# as_chirps for batch_idx 37
# start mining for batch_idx 37 with support = 0.1
# found 48 patterns from 500 trees for batch_idx 37
# start score sort for batch_idx 37 (48) patterns
# start merge rule for batch_idx 37 (48) patterns
# [('capital-gain', True, -0.85816), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.10510517836424611 0.21202245156617774
# merge complete for batch_idx 37 (48) patterns
# start get explainer for batch_idx 37
# as_chirps for batch_idx 38
# start mining for batch_idx 38 with support = 0.1
# reduced 2 patterns out of 43 by numeric redundancy
# found 41 patterns from 500 trees for batch_idx 38
# start score sort for batch_idx 38 (41) patterns
# start merge rule for batch_idx 38 (41) patterns
# [('capital-gain', False, -0.898)]
# 0.9544678429140581 0.048436727275775304 0.12956152060941492 0.22259810554803783
# merge complete for batch_idx 38 (41) patterns
# start get explainer for batch_idx 38
# as_chirps for batch_idx 39
# start mining for batch_idx 39 with support = 0.1
# found 73 patterns from 265 trees for batch_idx 39
# start score sort for batch_idx 39 (73) patterns
# start merge rule for batch_idx 39 (73) patterns
# [('capital-gain', True, -0.898), ('occupation_Exec-managerial', True, 0.0), ('occupation_Prof-specialty', True, 0.0), ('capital-loss', True, -0.17882)]
# 0.9526023043305523 0.5770919913755098 0.104451846675026 0.10946159936658745
# merge complete for batch_idx 39 (73) patterns
# start get explainer for batch_idx 39
# Working on CHIRPS for instance 40 of 1000
# as_chirps for batch_idx 40
# start mining for batch_idx 40 with support = 0.1
# found 69 patterns from 500 trees for batch_idx 40
# start score sort for batch_idx 40 (69) patterns
# start merge rule for batch_idx 40 (69) patterns
# [('capital-gain', True, -0.85816), ('capital-loss', True, 0.05375), ('marital-status_Married', True, 0.0)]
# 0.9998915636521362 0.5103497896834182 0.1843436227962504 0.3150739704118353
# merge complete for batch_idx 40 (69) patterns
# start get explainer for batch_idx 40
# as_chirps for batch_idx 41
# start mining for batch_idx 41 with support = 0.1
# found 50 patterns from 500 trees for batch_idx 41
# start score sort for batch_idx 41 (50) patterns
# start merge rule for batch_idx 41 (50) patterns
# [('capital-gain', True, -0.85816), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.10429523257689072 0.20466411416637656
# merge complete for batch_idx 41 (50) patterns
# start get explainer for batch_idx 41
# as_chirps for batch_idx 42
# start mining for batch_idx 42 with support = 0.1
# found 48 patterns from 500 trees for batch_idx 42
# start score sort for batch_idx 42 (48) patterns
# start merge rule for batch_idx 42 (48) patterns
# [('capital-gain', True, -0.85796), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.0869178940535019 0.13397745571658617
# merge complete for batch_idx 42 (48) patterns
# start get explainer for batch_idx 42
# as_chirps for batch_idx 43
# start mining for batch_idx 43 with support = 0.1
# found 58 patterns from 500 trees for batch_idx 43
# start score sort for batch_idx 43 (58) patterns
# start merge rule for batch_idx 43 (58) patterns
# [('marital-status_Married', True, 0.0), ('capital-gain', True, -0.85834)]
# 0.9972468149427769 0.5089488501125855 0.0953492006480307 0.17121078862503666
# merge complete for batch_idx 43 (58) patterns
# start get explainer for batch_idx 43
# as_chirps for batch_idx 44
# start mining for batch_idx 44 with support = 0.1
# found 58 patterns from 500 trees for batch_idx 44
# start score sort for batch_idx 44 (58) patterns
# start merge rule for batch_idx 44 (58) patterns
# [('marital-status_Married', True, 0.0), ('capital-gain', True, -0.85834)]
# 0.9972468149427769 0.5089488501125855 0.09571395699385235 0.17302573203194327
# merge complete for batch_idx 44 (58) patterns
# start get explainer for batch_idx 44
# Working on CHIRPS for instance 45 of 1000
# as_chirps for batch_idx 45
# start mining for batch_idx 45 with support = 0.1
# found 70 patterns from 488 trees for batch_idx 45
# start score sort for batch_idx 45 (70) patterns
# start merge rule for batch_idx 45 (70) patterns
# [('capital-gain', True, -0.898), ('education_Elementary-school', False, -0.125), ('education_HS-grad', True, 0.0)]
# 0.998274374460742 0.032017932255922074 0.05890212690184906 0.0760616476327753
# merge complete for batch_idx 45 (70) patterns
# start get explainer for batch_idx 45
# as_chirps for batch_idx 46
# start mining for batch_idx 46 with support = 0.1
# found 56 patterns from 500 trees for batch_idx 46
# start score sort for batch_idx 46 (56) patterns
# start merge rule for batch_idx 46 (56) patterns
# [('marital-status_Married', True, 0.0), ('capital-gain', True, -0.85834)]
# 0.9972468149427769 0.5089488501125855 0.1932134128696394 0.3144749551538568
# merge complete for batch_idx 46 (56) patterns
# start get explainer for batch_idx 46
# as_chirps for batch_idx 47
# start mining for batch_idx 47 with support = 0.1
# found 52 patterns from 500 trees for batch_idx 47
# start score sort for batch_idx 47 (52) patterns
# start merge rule for batch_idx 47 (52) patterns
# [('capital-gain', True, -0.85816), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.10658731462032006 0.15210740992522093
# merge complete for batch_idx 47 (52) patterns
# start get explainer for batch_idx 47
# as_chirps for batch_idx 48
# start mining for batch_idx 48 with support = 0.1
# found 70 patterns from 172 trees for batch_idx 48
# start score sort for batch_idx 48 (70) patterns
# start merge rule for batch_idx 48 (70) patterns
# [('capital-gain', True, -0.89799), ('occupation_Prof-specialty', True, 0.0), ('occupation_Exec-managerial', True, 0.0), ('education_Bachelors', True, 0.0), ('education_Masters', True, 0.0), ('capital-loss', True, -0.15243)]
# 0.9997326322356401 0.6206022180137238 0.13257216802614777 0.15874999999999997
# merge complete for batch_idx 48 (70) patterns
# start get explainer for batch_idx 48
# as_chirps for batch_idx 49
# start mining for batch_idx 49 with support = 0.1
# found 46 patterns from 500 trees for batch_idx 49
# start score sort for batch_idx 49 (46) patterns
# start merge rule for batch_idx 49 (46) patterns
# [('capital-gain', True, -0.85812), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.09492337356891488 0.141703130259172
# merge complete for batch_idx 49 (46) patterns
# start get explainer for batch_idx 49
# Working on CHIRPS for instance 50 of 1000
# as_chirps for batch_idx 50
# start mining for batch_idx 50 with support = 0.1
# found 64 patterns from 500 trees for batch_idx 50
# start score sort for batch_idx 50 (64) patterns
# start merge rule for batch_idx 50 (64) patterns
# [('capital-gain', True, -0.85816), ('capital-loss', True, 0.05382), ('marital-status_Married', True, 0.0)]
# 0.9998915636521362 0.5103497896834182 0.20076578978499648 0.3369487655201942
# merge complete for batch_idx 50 (64) patterns
# start get explainer for batch_idx 50
# as_chirps for batch_idx 51
# start mining for batch_idx 51 with support = 0.1
# found 63 patterns from 424 trees for batch_idx 51
# start score sort for batch_idx 51 (63) patterns
# start merge rule for batch_idx 51 (63) patterns
# [('marital-status_Married', True, 0.0), ('capital-gain', True, -0.85807)]
# 0.9972468149427769 0.5089488501125855 0.0867926690722363 0.13997529847673942
# merge complete for batch_idx 51 (63) patterns
# start get explainer for batch_idx 51
# as_chirps for batch_idx 52
# start mining for batch_idx 52 with support = 0.1
# found 58 patterns from 500 trees for batch_idx 52
# start score sort for batch_idx 52 (58) patterns
# start merge rule for batch_idx 52 (58) patterns
# [('capital-gain', True, -0.85793), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.09372806961902734 0.16891402058866173
# merge complete for batch_idx 52 (58) patterns
# start get explainer for batch_idx 52
# as_chirps for batch_idx 53
# start mining for batch_idx 53 with support = 0.1
# reduced 2 patterns out of 42 by numeric redundancy
# found 40 patterns from 500 trees for batch_idx 53
# start score sort for batch_idx 53 (40) patterns
# start merge rule for batch_idx 53 (40) patterns
# [('capital-gain', False, -0.898)]
# 0.9544678429140581 0.048436727275775304 0.1343001773076456 0.2255806010928962
# merge complete for batch_idx 53 (40) patterns
# start get explainer for batch_idx 53
# as_chirps for batch_idx 54
# start mining for batch_idx 54 with support = 0.1
# found 57 patterns from 500 trees for batch_idx 54
# start score sort for batch_idx 54 (57) patterns
# start merge rule for batch_idx 54 (57) patterns
# [('marital-status_Married', True, 0.0), ('capital-gain', True, -0.85834)]
# 0.9972468149427769 0.5089488501125855 0.18833877761765844 0.3126370614035088
# merge complete for batch_idx 54 (57) patterns
# start get explainer for batch_idx 54
# Working on CHIRPS for instance 55 of 1000
# as_chirps for batch_idx 55
# start mining for batch_idx 55 with support = 0.1
# found 49 patterns from 500 trees for batch_idx 55
# start score sort for batch_idx 55 (49) patterns
# start merge rule for batch_idx 55 (49) patterns
# [('capital-gain', True, -0.85812), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.09182969519831612 0.1434412265758092
# merge complete for batch_idx 55 (49) patterns
# start get explainer for batch_idx 55
# as_chirps for batch_idx 56
# start mining for batch_idx 56 with support = 0.1
# found 56 patterns from 500 trees for batch_idx 56
# start score sort for batch_idx 56 (56) patterns
# start merge rule for batch_idx 56 (56) patterns
# [('marital-status_Married', True, 0.0), ('capital-gain', True, -0.85834)]
# 0.9972468149427769 0.5089488501125855 0.1932133389907889 0.3144749551538568
# merge complete for batch_idx 56 (56) patterns
# start get explainer for batch_idx 56
# as_chirps for batch_idx 57
# start mining for batch_idx 57 with support = 0.1
# found 46 patterns from 500 trees for batch_idx 57
# start score sort for batch_idx 57 (46) patterns
# start merge rule for batch_idx 57 (46) patterns
# [('capital-gain', True, -0.85812), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.0912519129029041 0.13046172916021073
# merge complete for batch_idx 57 (46) patterns
# start get explainer for batch_idx 57
# as_chirps for batch_idx 58
# start mining for batch_idx 58 with support = 0.1
# found 70 patterns from 488 trees for batch_idx 58
# start score sort for batch_idx 58 (70) patterns
# start merge rule for batch_idx 58 (70) patterns
# [('capital-gain', True, -0.898), ('education_Elementary-school', False, -0.125), ('education_HS-grad', True, 0.0)]
# 0.998274374460742 0.032017932255922074 0.058902143385401874 0.0760616476327753
# merge complete for batch_idx 58 (70) patterns
# start get explainer for batch_idx 58
# as_chirps for batch_idx 59
# start mining for batch_idx 59 with support = 0.1
# found 47 patterns from 500 trees for batch_idx 59
# start score sort for batch_idx 59 (47) patterns
# start merge rule for batch_idx 59 (47) patterns
# [('capital-gain', True, -0.85812), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.08720157441348125 0.12194062273714702
# merge complete for batch_idx 59 (47) patterns
# start get explainer for batch_idx 59
# Working on CHIRPS for instance 60 of 1000
# as_chirps for batch_idx 60
# start mining for batch_idx 60 with support = 0.1
# reduced 2 patterns out of 43 by numeric redundancy
# found 41 patterns from 500 trees for batch_idx 60
# start score sort for batch_idx 60 (41) patterns
# start merge rule for batch_idx 60 (41) patterns
# [('capital-gain', False, -0.898)]
# 0.9544678429140581 0.048436727275775304 0.1295245591068595 0.22241000507013686
# merge complete for batch_idx 60 (41) patterns
# start get explainer for batch_idx 60
# as_chirps for batch_idx 61
# start mining for batch_idx 61 with support = 0.1
# found 45 patterns from 500 trees for batch_idx 61
# start score sort for batch_idx 61 (45) patterns
# start merge rule for batch_idx 61 (45) patterns
# [('capital-gain', True, -0.85817), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.11268658508883486 0.21807720861172986
# merge complete for batch_idx 61 (45) patterns
# start get explainer for batch_idx 61
# as_chirps for batch_idx 62
# start mining for batch_idx 62 with support = 0.1
# found 50 patterns from 500 trees for batch_idx 62
# start score sort for batch_idx 62 (50) patterns
# start merge rule for batch_idx 62 (50) patterns
# [('capital-gain', True, -0.85796), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.08064081013854348 0.12632857576677806
# merge complete for batch_idx 62 (50) patterns
# start get explainer for batch_idx 62
# as_chirps for batch_idx 63
# start mining for batch_idx 63 with support = 0.1
# found 52 patterns from 500 trees for batch_idx 63
# start score sort for batch_idx 63 (52) patterns
# start merge rule for batch_idx 63 (52) patterns
# [('capital-gain', True, -0.85816), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.10642401039243028 0.15125908399526786
# merge complete for batch_idx 63 (52) patterns
# start get explainer for batch_idx 63
# as_chirps for batch_idx 64
# start mining for batch_idx 64 with support = 0.1
# found 52 patterns from 500 trees for batch_idx 64
# start score sort for batch_idx 64 (52) patterns
# start merge rule for batch_idx 64 (52) patterns
# [('capital-gain', True, -0.898), ('education_HS-grad', False, -0.125), ('capital-loss', True, -0.17839)]
# 0.9998615342010524 0.3996568518928492 0.2037589423347585 0.20068858285206564
# merge complete for batch_idx 64 (52) patterns
# start get explainer for batch_idx 64
# Working on CHIRPS for instance 65 of 1000
# as_chirps for batch_idx 65
# start mining for batch_idx 65 with support = 0.1
# found 65 patterns from 201 trees for batch_idx 65
# start score sort for batch_idx 65 (65) patterns
# start merge rule for batch_idx 65 (65) patterns
# [('capital-gain', True, -0.89799), ('education_Bachelors', True, 0.0), ('occupation_Exec-managerial', True, 0.0), ('occupation_Prof-specialty', True, 0.0)]
# 0.9803988995873453 0.6016715111555156 0.053374368547525496 0.05258467023172903
# merge complete for batch_idx 65 (65) patterns
# start get explainer for batch_idx 65
# as_chirps for batch_idx 66
# start mining for batch_idx 66 with support = 0.1
# found 56 patterns from 500 trees for batch_idx 66
# start score sort for batch_idx 66 (56) patterns
# start merge rule for batch_idx 66 (56) patterns
# [('marital-status_Married', True, 0.0), ('capital-gain', True, -0.85834)]
# 0.9972468149427769 0.5089488501125855 0.09536573358890385 0.1773923626958771
# merge complete for batch_idx 66 (56) patterns
# start get explainer for batch_idx 66
# as_chirps for batch_idx 67
# start mining for batch_idx 67 with support = 0.1
# found 51 patterns from 500 trees for batch_idx 67
# start score sort for batch_idx 67 (51) patterns
# start merge rule for batch_idx 67 (51) patterns
# [('capital-gain', True, -0.85816), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.1007797805686143 0.20270036351047258
# merge complete for batch_idx 67 (51) patterns
# start get explainer for batch_idx 67
# as_chirps for batch_idx 68
# start mining for batch_idx 68 with support = 0.1
# found 63 patterns from 423 trees for batch_idx 68
# start score sort for batch_idx 68 (63) patterns
# start merge rule for batch_idx 68 (63) patterns
# [('education_Bachelors', False, -0.125), ('marital-status_Married', False, -0.125)]
# 0.9677215189873418 0.08709263263685976 0.1138731369694172 0.06779053084648488
# merge complete for batch_idx 68 (63) patterns
# start get explainer for batch_idx 68
# as_chirps for batch_idx 69
# start mining for batch_idx 69 with support = 0.1
# found 52 patterns from 500 trees for batch_idx 69
# start score sort for batch_idx 69 (52) patterns
# start merge rule for batch_idx 69 (52) patterns
# [('capital-gain', True, -0.85816), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.1065872435291279 0.15210740992522093
# merge complete for batch_idx 69 (52) patterns
# start get explainer for batch_idx 69
# Working on CHIRPS for instance 70 of 1000
# as_chirps for batch_idx 70
# start mining for batch_idx 70 with support = 0.1
# found 58 patterns from 500 trees for batch_idx 70
# start score sort for batch_idx 70 (58) patterns
# start merge rule for batch_idx 70 (58) patterns
# [('marital-status_Married', True, 0.0), ('capital-gain', True, -0.85834)]
# 0.9972468149427769 0.5089488501125855 0.09286378490260129 0.17344497607655507
# merge complete for batch_idx 70 (58) patterns
# start get explainer for batch_idx 70
# as_chirps for batch_idx 71
# start mining for batch_idx 71 with support = 0.1
# found 59 patterns from 500 trees for batch_idx 71
# start score sort for batch_idx 71 (59) patterns
# start merge rule for batch_idx 71 (59) patterns
# [('marital-status_Married', True, 0.0), ('capital-gain', True, -0.85834)]
# 0.9972468149427769 0.5089488501125855 0.09322863609896051 0.17173051519154559
# merge complete for batch_idx 71 (59) patterns
# start get explainer for batch_idx 71
# as_chirps for batch_idx 72
# start mining for batch_idx 72 with support = 0.1
# found 57 patterns from 347 trees for batch_idx 72
# start score sort for batch_idx 72 (57) patterns
# start merge rule for batch_idx 72 (57) patterns
# [('education_HS-grad', True, 0.0), ('marital-status_Married', False, -0.125), ('occupation_Exec-managerial', False, -0.125), ('education_Elementary-school', True, 0.0)]
# 0.9551310528653931 0.06202598646144015 0.2863405619258727 0.26896077081899505
# merge complete for batch_idx 72 (57) patterns
# start get explainer for batch_idx 72
# as_chirps for batch_idx 73
# start mining for batch_idx 73 with support = 0.1
# found 51 patterns from 500 trees for batch_idx 73
# start score sort for batch_idx 73 (51) patterns
# start merge rule for batch_idx 73 (51) patterns
# [('capital-gain', True, -0.85816), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.10077976905522226 0.2027003635104726
# merge complete for batch_idx 73 (51) patterns
# start get explainer for batch_idx 73
# as_chirps for batch_idx 74
# start mining for batch_idx 74 with support = 0.1
# found 68 patterns from 383 trees for batch_idx 74
# start score sort for batch_idx 74 (68) patterns
# start merge rule for batch_idx 74 (68) patterns
# [('education_Bachelors', False, -0.125), ('marital-status_Married', False, -0.125)]
# 0.9677215189873418 0.08709263263685976 0.06910796652910876 0.05234093637454979
# merge complete for batch_idx 74 (68) patterns
# start get explainer for batch_idx 74
# Working on CHIRPS for instance 75 of 1000
# as_chirps for batch_idx 75
# start mining for batch_idx 75 with support = 0.1
# found 52 patterns from 500 trees for batch_idx 75
# start score sort for batch_idx 75 (52) patterns
# start merge rule for batch_idx 75 (52) patterns
# [('marital-status_Married', True, 0.0), ('capital-gain', True, -0.85833)]
# 0.9972468149427769 0.5089488501125855 0.10877303832201222 0.14015606242497003
# merge complete for batch_idx 75 (52) patterns
# start get explainer for batch_idx 75
# as_chirps for batch_idx 76
# start mining for batch_idx 76 with support = 0.1
# found 52 patterns from 500 trees for batch_idx 76
# start score sort for batch_idx 76 (52) patterns
# start merge rule for batch_idx 76 (52) patterns
# [('capital-gain', True, -0.898), ('education_HS-grad', False, -0.125), ('capital-loss', True, -0.17836)]
# 0.9998615342010524 0.3996568518928492 0.1999595629820921 0.19342442356959855
# merge complete for batch_idx 76 (52) patterns
# start get explainer for batch_idx 76
# as_chirps for batch_idx 77
# start mining for batch_idx 77 with support = 0.1
# found 52 patterns from 500 trees for batch_idx 77
# start score sort for batch_idx 77 (52) patterns
# start merge rule for batch_idx 77 (52) patterns
# [('capital-gain', True, -0.898), ('education_HS-grad', False, -0.125), ('capital-loss', True, -0.17839)]
# 0.9998615342010524 0.3996568518928492 0.20375888293106004 0.20068858285206564
# merge complete for batch_idx 77 (52) patterns
# start get explainer for batch_idx 77
# as_chirps for batch_idx 78
# start mining for batch_idx 78 with support = 0.1
# found 66 patterns from 456 trees for batch_idx 78
# start score sort for batch_idx 78 (66) patterns
# start merge rule for batch_idx 78 (66) patterns
# [('education_HS-grad', True, 0.0), ('marital-status_Married', False, -0.125), ('education_Bachelors', False, -0.125)]
# 0.9677215189873418 0.08709263263685976 0.21556919927062856 0.1704055696762073
# merge complete for batch_idx 78 (66) patterns
# start get explainer for batch_idx 78
# as_chirps for batch_idx 79
# start mining for batch_idx 79 with support = 0.1
# found 52 patterns from 500 trees for batch_idx 79
# start score sort for batch_idx 79 (52) patterns
# start merge rule for batch_idx 79 (52) patterns
# [('capital-gain', True, -0.85816), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.10658726279258375 0.15210740992522093
# merge complete for batch_idx 79 (52) patterns
# start get explainer for batch_idx 79
# Working on CHIRPS for instance 80 of 1000
# as_chirps for batch_idx 80
# start mining for batch_idx 80 with support = 0.1
# found 37 patterns from 478 trees for batch_idx 80
# start score sort for batch_idx 80 (37) patterns
# start merge rule for batch_idx 80 (37) patterns
# [('capital-gain', True, -0.898), ('education_HS-grad', False, -0.125), ('capital-loss', True, -0.1748)]
# 0.9998615342010524 0.3996568518928492 0.15883876906037264 0.18325642715886623
# merge complete for batch_idx 80 (37) patterns
# start get explainer for batch_idx 80
# as_chirps for batch_idx 81
# start mining for batch_idx 81 with support = 0.1
# reduced 4 patterns out of 59 by numeric redundancy
# found 55 patterns from 391 trees for batch_idx 81
# start score sort for batch_idx 81 (55) patterns
# start merge rule for batch_idx 81 (55) patterns
# [('capital-loss', False, -0.15898), ('education_HS-grad', True, 0.0), ('marital-status_Married', False, -0.125), ('education_Elementary-school', True, 0.0)]
# 0.9968203497615262 0.017351117998671686 0.2988083110112577 0.30154727793696273
# merge complete for batch_idx 81 (55) patterns
# start get explainer for batch_idx 81
# as_chirps for batch_idx 82
# start mining for batch_idx 82 with support = 0.1
# found 52 patterns from 500 trees for batch_idx 82
# start score sort for batch_idx 82 (52) patterns
# start merge rule for batch_idx 82 (52) patterns
# [('capital-gain', True, -0.85816), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.10658726838436809 0.15210740992522093
# merge complete for batch_idx 82 (52) patterns
# start get explainer for batch_idx 82
# as_chirps for batch_idx 83
# start mining for batch_idx 83 with support = 0.1
# found 57 patterns from 500 trees for batch_idx 83
# start score sort for batch_idx 83 (57) patterns
# start merge rule for batch_idx 83 (57) patterns
# [('marital-status_Married', True, 0.0), ('capital-gain', True, -0.85834)]
# 0.9972468149427769 0.5089488501125855 0.1890890302239816 0.31655776449325745
# merge complete for batch_idx 83 (57) patterns
# start get explainer for batch_idx 83
# as_chirps for batch_idx 84
# start mining for batch_idx 84 with support = 0.1
# found 63 patterns from 500 trees for batch_idx 84
# start score sort for batch_idx 84 (63) patterns
# start merge rule for batch_idx 84 (63) patterns
# [('capital-gain', True, -0.85816), ('capital-loss', True, 0.0539), ('marital-status_Married', True, 0.0)]
# 0.9998915636521362 0.5103497896834182 0.2046126718669564 0.338304890291123
# merge complete for batch_idx 84 (63) patterns
# start get explainer for batch_idx 84
# Working on CHIRPS for instance 85 of 1000
# as_chirps for batch_idx 85
# start mining for batch_idx 85 with support = 0.1
# found 52 patterns from 500 trees for batch_idx 85
# start score sort for batch_idx 85 (52) patterns
# start merge rule for batch_idx 85 (52) patterns
# [('capital-gain', True, -0.898), ('education_HS-grad', False, -0.125), ('capital-loss', True, -0.17839)]
# 0.9998615342010524 0.3996568518928492 0.20375882670026763 0.20068858285206564
# merge complete for batch_idx 85 (52) patterns
# start get explainer for batch_idx 85
# as_chirps for batch_idx 86
# start mining for batch_idx 86 with support = 0.1
# found 66 patterns from 453 trees for batch_idx 86
# start score sort for batch_idx 86 (66) patterns
# start merge rule for batch_idx 86 (66) patterns
# [('education_HS-grad', True, 0.0), ('marital-status_Married', False, -0.125), ('education_Bachelors', False, -0.125)]
# 0.9677215189873418 0.08709263263685976 0.21525888658608816 0.17004991680532439
# merge complete for batch_idx 86 (66) patterns
# start get explainer for batch_idx 86
# as_chirps for batch_idx 87
# start mining for batch_idx 87 with support = 0.1
# found 54 patterns from 500 trees for batch_idx 87
# start score sort for batch_idx 87 (54) patterns
# start merge rule for batch_idx 87 (54) patterns
# [('marital-status_Married', True, 0.0), ('capital-gain', True, -0.85835)]
# 0.9972468149427769 0.5089488501125855 0.09954476155415118 0.18055125425828436
# merge complete for batch_idx 87 (54) patterns
# start get explainer for batch_idx 87
# as_chirps for batch_idx 88
# start mining for batch_idx 88 with support = 0.1
# found 52 patterns from 500 trees for batch_idx 88
# start score sort for batch_idx 88 (52) patterns
# start merge rule for batch_idx 88 (52) patterns
# [('capital-gain', True, -0.85816), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.10658724550179217 0.15210740992522093
# merge complete for batch_idx 88 (52) patterns
# start get explainer for batch_idx 88
# as_chirps for batch_idx 89
# start mining for batch_idx 89 with support = 0.1
# reduced 2 patterns out of 40 by numeric redundancy
# found 38 patterns from 381 trees for batch_idx 89
# start score sort for batch_idx 89 (38) patterns
# start merge rule for batch_idx 89 (38) patterns
# [('capital-loss', False, 0.09407)]
# 0.8615384615384616 0.0035402320944738527 0.23398978886119803 0.23381737632291416
# merge complete for batch_idx 89 (38) patterns
# start get explainer for batch_idx 89
# Working on CHIRPS for instance 90 of 1000
# as_chirps for batch_idx 90
# start mining for batch_idx 90 with support = 0.1
# found 58 patterns from 500 trees for batch_idx 90
# start score sort for batch_idx 90 (58) patterns
# start merge rule for batch_idx 90 (58) patterns
# [('marital-status_Married', True, 0.0), ('capital-gain', True, -0.85834)]
# 0.9972468149427769 0.5089488501125855 0.09495338996990105 0.17431466030989276
# merge complete for batch_idx 90 (58) patterns
# start get explainer for batch_idx 90
# as_chirps for batch_idx 91
# start mining for batch_idx 91 with support = 0.1
# found 48 patterns from 499 trees for batch_idx 91
# start score sort for batch_idx 91 (48) patterns
# start merge rule for batch_idx 91 (48) patterns
# [('marital-status_Married', True, 0.0), ('capital-gain', True, -0.8582)]
# 0.9972468149427769 0.5089488501125855 0.12769325712407864 0.21100752958049473
# merge complete for batch_idx 91 (48) patterns
# start get explainer for batch_idx 91
# as_chirps for batch_idx 92
# start mining for batch_idx 92 with support = 0.1
# found 52 patterns from 500 trees for batch_idx 92
# start score sort for batch_idx 92 (52) patterns
# start merge rule for batch_idx 92 (52) patterns
# [('capital-gain', True, -0.85816), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.10658724550179217 0.15210740992522093
# merge complete for batch_idx 92 (52) patterns
# start get explainer for batch_idx 92
# as_chirps for batch_idx 93
# start mining for batch_idx 93 with support = 0.1
# found 57 patterns from 500 trees for batch_idx 93
# start score sort for batch_idx 93 (57) patterns
# start merge rule for batch_idx 93 (57) patterns
# [('capital-gain', True, -0.85793), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.0946889534510065 0.17007804447062286
# merge complete for batch_idx 93 (57) patterns
# start get explainer for batch_idx 93
# as_chirps for batch_idx 94
# start mining for batch_idx 94 with support = 0.1
# found 54 patterns from 500 trees for batch_idx 94
# start score sort for batch_idx 94 (54) patterns
# start merge rule for batch_idx 94 (54) patterns
# [('capital-gain', True, -0.898), ('education_HS-grad', False, -0.125), ('capital-loss', True, -0.17793)]
# 0.9998615342010524 0.3996568518928492 0.2039251098098016 0.22657685241886094
# merge complete for batch_idx 94 (54) patterns
# start get explainer for batch_idx 94
# Working on CHIRPS for instance 95 of 1000
# as_chirps for batch_idx 95
# start mining for batch_idx 95 with support = 0.1
# found 59 patterns from 498 trees for batch_idx 95
# start score sort for batch_idx 95 (59) patterns
# start merge rule for batch_idx 95 (59) patterns
# [('marital-status_Married', True, 0.0), ('capital-gain', True, -0.85834)]
# 0.9972468149427769 0.5089488501125855 0.09337825070555525 0.17200823287268455
# merge complete for batch_idx 95 (59) patterns
# start get explainer for batch_idx 95
# as_chirps for batch_idx 96
# start mining for batch_idx 96 with support = 0.1
# found 68 patterns from 386 trees for batch_idx 96
# start score sort for batch_idx 96 (68) patterns
# start merge rule for batch_idx 96 (68) patterns
# [('education_Bachelors', False, -0.125), ('marital-status_Married', False, -0.125)]
# 0.9677215189873418 0.08709263263685976 0.06917988937970267 0.05237981344176032
# merge complete for batch_idx 96 (68) patterns
# start get explainer for batch_idx 96
# as_chirps for batch_idx 97
# start mining for batch_idx 97 with support = 0.1
# found 45 patterns from 500 trees for batch_idx 97
# start score sort for batch_idx 97 (45) patterns
# start merge rule for batch_idx 97 (45) patterns
# [('capital-gain', True, -0.85816), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.1123873207952432 0.21733505821474763
# merge complete for batch_idx 97 (45) patterns
# start get explainer for batch_idx 97
# as_chirps for batch_idx 98
# start mining for batch_idx 98 with support = 0.1
# found 52 patterns from 500 trees for batch_idx 98
# ...
# 0.9551310528653931 0.06202598646144015 0.28634056911098604 0.26896077081899505
# merge complete for batch_idx 969 (57) patterns
# start get explainer for batch_idx 969
# Working on CHIRPS for instance 970 of 1000
# as_chirps for batch_idx 970
# start mining for batch_idx 970 with support = 0.1
# reduced 2 patterns out of 42 by numeric redundancy
# found 40 patterns from 500 trees for batch_idx 970
# start score sort for batch_idx 970 (40) patterns
# start merge rule for batch_idx 970 (40) patterns
# [('capital-gain', False, -0.898)]
# 0.9544678429140581 0.048436727275775304 0.1341820871718911 0.2252390710382514
# merge complete for batch_idx 970 (40) patterns
# start get explainer for batch_idx 970
# as_chirps for batch_idx 971
# start mining for batch_idx 971 with support = 0.1
# found 58 patterns from 500 trees for batch_idx 971
# start score sort for batch_idx 971 (58) patterns
# start merge rule for batch_idx 971 (58) patterns
# [('capital-gain', True, -0.85816), ('capital-loss', True, 0.05382), ('marital-status_Married', True, 0.0)]
# 0.9998915636521362 0.5103497896834182 0.21814144996388868 0.35165326184092954
# merge complete for batch_idx 971 (58) patterns
# start get explainer for batch_idx 971
# as_chirps for batch_idx 972
# start mining for batch_idx 972 with support = 0.1
# found 60 patterns from 500 trees for batch_idx 972
# start score sort for batch_idx 972 (60) patterns
# start merge rule for batch_idx 972 (60) patterns
# [('capital-gain', True, -0.8581), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.10134548176641396 0.18024985127900053
# merge complete for batch_idx 972 (60) patterns
# start get explainer for batch_idx 972
# as_chirps for batch_idx 973
# start mining for batch_idx 973 with support = 0.1
# reduced 4 patterns out of 56 by numeric redundancy
# found 52 patterns from 495 trees for batch_idx 973
# start score sort for batch_idx 973 (52) patterns
# start merge rule for batch_idx 973 (52) patterns
# [('capital-gain', False, -0.898)]
# 0.9544678429140581 0.048436727275775304 0.10689886304161056 0.2127937336814622
# merge complete for batch_idx 973 (52) patterns
# start get explainer for batch_idx 973
# as_chirps for batch_idx 974
# start mining for batch_idx 974 with support = 0.1
# found 50 patterns from 500 trees for batch_idx 974
# start score sort for batch_idx 974 (50) patterns
# start merge rule for batch_idx 974 (50) patterns
# [('capital-gain', True, -0.85817), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.10436193375781999 0.20476273248739785
# merge complete for batch_idx 974 (50) patterns
# start get explainer for batch_idx 974
# Working on CHIRPS for instance 975 of 1000
# as_chirps for batch_idx 975
# start mining for batch_idx 975 with support = 0.1
# found 52 patterns from 500 trees for batch_idx 975
# start score sort for batch_idx 975 (52) patterns
# start merge rule for batch_idx 975 (52) patterns
# [('capital-gain', True, -0.898), ('education_HS-grad', False, -0.125), ('capital-loss', True, -0.17839)]
# 0.9998615342010524 0.3996568518928492 0.2037589423347585 0.20068858285206564
# merge complete for batch_idx 975 (52) patterns
# start get explainer for batch_idx 975
# as_chirps for batch_idx 976
# start mining for batch_idx 976 with support = 0.1
# found 52 patterns from 500 trees for batch_idx 976
# start score sort for batch_idx 976 (52) patterns
# start merge rule for batch_idx 976 (52) patterns
# [('capital-gain', True, -0.898), ('education_HS-grad', False, -0.125), ('capital-loss', True, -0.17839)]
# 0.9998615342010524 0.3996568518928492 0.20375888293106004 0.20068858285206564
# merge complete for batch_idx 976 (52) patterns
# start get explainer for batch_idx 976
# as_chirps for batch_idx 977
# start mining for batch_idx 977 with support = 0.1
# found 47 patterns from 500 trees for batch_idx 977
# start score sort for batch_idx 977 (47) patterns
# start merge rule for batch_idx 977 (47) patterns
# [('capital-gain', True, -0.85816), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.13678993909471765 0.22746781115879833
# merge complete for batch_idx 977 (47) patterns
# start get explainer for batch_idx 977
# as_chirps for batch_idx 978
# start mining for batch_idx 978 with support = 0.1
# found 57 patterns from 401 trees for batch_idx 978
# start score sort for batch_idx 978 (57) patterns
# start merge rule for batch_idx 978 (57) patterns
# [('capital-loss', False, -0.17839), ('capital-loss', True, -0.08659), ('marital-status_Married', False, -0.125)]
# 0.9924924924924925 0.01837313885764357 0.1091614563072913 0.13826496301277733
# merge complete for batch_idx 978 (57) patterns
# start get explainer for batch_idx 978
# as_chirps for batch_idx 979
# start mining for batch_idx 979 with support = 0.1
# found 59 patterns from 500 trees for batch_idx 979
# start score sort for batch_idx 979 (59) patterns
# start merge rule for batch_idx 979 (59) patterns
# [('capital-gain', True, -0.898), ('education_HS-grad', False, -0.125)]
# 0.9892210697579825 0.3989297444286785 0.1518057573678903 0.18737138524856492
# merge complete for batch_idx 979 (59) patterns
# start get explainer for batch_idx 979
# Working on CHIRPS for instance 980 of 1000
# as_chirps for batch_idx 980
# start mining for batch_idx 980 with support = 0.1
# found 62 patterns from 482 trees for batch_idx 980
# start score sort for batch_idx 980 (62) patterns
# start merge rule for batch_idx 980 (62) patterns
# [('marital-status_Married', True, 0.0), ('capital-gain', True, -0.85833)]
# 0.9972468149427769 0.5089488501125855 0.13652554075304235 0.16528215411057018
# merge complete for batch_idx 980 (62) patterns
# start get explainer for batch_idx 980
# as_chirps for batch_idx 981
# start mining for batch_idx 981 with support = 0.1
# found 52 patterns from 500 trees for batch_idx 981
# start score sort for batch_idx 981 (52) patterns
# start merge rule for batch_idx 981 (52) patterns
# [('capital-gain', True, -0.898), ('education_HS-grad', False, -0.125), ('capital-loss', True, -0.17839)]
# 0.9998615342010524 0.3996568518928492 0.20375885606424854 0.20068858285206564
# merge complete for batch_idx 981 (52) patterns
# start get explainer for batch_idx 981
# as_chirps for batch_idx 982
# start mining for batch_idx 982 with support = 0.1
# found 70 patterns from 172 trees for batch_idx 982
# start score sort for batch_idx 982 (70) patterns
# start merge rule for batch_idx 982 (70) patterns
# [('capital-gain', True, -0.89799), ('occupation_Prof-specialty', True, 0.0), ('occupation_Exec-managerial', True, 0.0), ('education_Bachelors', True, 0.0), ('education_Masters', True, 0.0), ('capital-loss', True, -0.15243)]
# 0.9997326322356401 0.6206022180137238 0.132572176573758 0.15874999999999997
# merge complete for batch_idx 982 (70) patterns
# start get explainer for batch_idx 982
# as_chirps for batch_idx 983
# start mining for batch_idx 983 with support = 0.1
# found 57 patterns from 500 trees for batch_idx 983
# start score sort for batch_idx 983 (57) patterns
# start merge rule for batch_idx 983 (57) patterns
# [('marital-status_Married', True, 0.0), ('capital-gain', True, -0.85834)]
# 0.9972468149427769 0.5089488501125855 0.18817775921884222 0.31221719457013575
# merge complete for batch_idx 983 (57) patterns
# start get explainer for batch_idx 983
# as_chirps for batch_idx 984
# start mining for batch_idx 984 with support = 0.1
# found 59 patterns from 500 trees for batch_idx 984
# start score sort for batch_idx 984 (59) patterns
# start merge rule for batch_idx 984 (59) patterns
# [('capital-gain', True, -0.898), ('education_HS-grad', False, -0.125)]
# 0.9892210697579825 0.3989297444286785 0.1523673408114074 0.18857513794222655
# merge complete for batch_idx 984 (59) patterns
# start get explainer for batch_idx 984
# Working on CHIRPS for instance 985 of 1000
# as_chirps for batch_idx 985
# start mining for batch_idx 985 with support = 0.1
# found 58 patterns from 500 trees for batch_idx 985
# start score sort for batch_idx 985 (58) patterns
# start merge rule for batch_idx 985 (58) patterns
# [('marital-status_Married', True, 0.0), ('capital-gain', True, -0.85834)]
# 0.9972468149427769 0.5089488501125855 0.09571395603467006 0.17302573203194327
# merge complete for batch_idx 985 (58) patterns
# start get explainer for batch_idx 985
# as_chirps for batch_idx 986
# start mining for batch_idx 986 with support = 0.1
# found 53 patterns from 465 trees for batch_idx 986
# start score sort for batch_idx 986 (53) patterns
# start merge rule for batch_idx 986 (53) patterns
# [('capital-gain', True, -0.898), ('education_HS-grad', False, -0.125), ('capital-loss', True, -0.17791)]
# 0.9998615342010524 0.3996568518928492 0.17466427803863885 0.20028142589118195
# merge complete for batch_idx 986 (53) patterns
# start get explainer for batch_idx 986
# as_chirps for batch_idx 987
# start mining for batch_idx 987 with support = 0.1
# found 65 patterns from 205 trees for batch_idx 987
# start score sort for batch_idx 987 (65) patterns
# start merge rule for batch_idx 987 (65) patterns
# [('capital-gain', True, -0.89799), ('education_Bachelors', True, 0.0), ('occupation_Exec-managerial', True, 0.0), ('occupation_Prof-specialty', True, 0.0)]
# 0.9803988995873453 0.6016715111555156 0.0530897010976228 0.05210772833723658
# merge complete for batch_idx 987 (65) patterns
# start get explainer for batch_idx 987
# as_chirps for batch_idx 988
# start mining for batch_idx 988 with support = 0.1
# found 68 patterns from 500 trees for batch_idx 988
# start score sort for batch_idx 988 (68) patterns
# start merge rule for batch_idx 988 (68) patterns
# [('capital-gain', True, -0.85808), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.08620973823439998 0.1566249516191459
# merge complete for batch_idx 988 (68) patterns
# start get explainer for batch_idx 988
# as_chirps for batch_idx 989
# start mining for batch_idx 989 with support = 0.1
# found 65 patterns from 395 trees for batch_idx 989
# start score sort for batch_idx 989 (65) patterns
# start merge rule for batch_idx 989 (65) patterns
# [('education_Elementary-school', True, 0.0), ('education_HS-grad', True, 0.0), ('marital-status_Married', False, -0.125), ('occupation_Prof-specialty', False, -0.125), ('education_Some-college', True, 0.0)]
# 0.9905660377358491 0.05857576136051463 0.30042772197244483 0.2553542009884679
# merge complete for batch_idx 989 (65) patterns
# start get explainer for batch_idx 989
# Working on CHIRPS for instance 990 of 1000
# as_chirps for batch_idx 990
# start mining for batch_idx 990 with support = 0.1
# found 77 patterns from 236 trees for batch_idx 990
# start score sort for batch_idx 990 (77) patterns
# start merge rule for batch_idx 990 (77) patterns
# [('capital-gain', True, -0.898), ('occupation_Exec-managerial', True, 0.0), ('occupation_Prof-specialty', True, 0.0), ('capital-loss', True, -0.17887)]
# 0.9526023043305523 0.5770919913755098 0.11372363513246955 0.12370925288519943
# merge complete for batch_idx 990 (77) patterns
# start get explainer for batch_idx 990
# as_chirps for batch_idx 991
# start mining for batch_idx 991 with support = 0.1
# reduced 2 patterns out of 44 by numeric redundancy
# found 42 patterns from 500 trees for batch_idx 991
# start score sort for batch_idx 991 (42) patterns
# start merge rule for batch_idx 991 (42) patterns
# [('capital-gain', False, -0.898)]
# 0.9544678429140581 0.048436727275775304 0.12881090686410362 0.2183832038353446
# merge complete for batch_idx 991 (42) patterns
# start get explainer for batch_idx 991
# as_chirps for batch_idx 992
# start mining for batch_idx 992 with support = 0.1
# found 52 patterns from 500 trees for batch_idx 992
# start score sort for batch_idx 992 (52) patterns
# start merge rule for batch_idx 992 (52) patterns
# [('capital-gain', True, -0.898), ('education_HS-grad', False, -0.125), ('capital-loss', True, -0.17839)]
# 0.9998615342010524 0.3996568518928492 0.20375885416709733 0.20068858285206564
# merge complete for batch_idx 992 (52) patterns
# start get explainer for batch_idx 992
# as_chirps for batch_idx 993
# start mining for batch_idx 993 with support = 0.1
# found 54 patterns from 500 trees for batch_idx 993
# start score sort for batch_idx 993 (54) patterns
# start merge rule for batch_idx 993 (54) patterns
# [('capital-gain', True, -0.898), ('education_HS-grad', False, -0.125), ('capital-loss', True, -0.17793)]
# 0.9998615342010524 0.3996568518928492 0.20392519764548817 0.22657685241886094
# merge complete for batch_idx 993 (54) patterns
# start get explainer for batch_idx 993
# as_chirps for batch_idx 994
# start mining for batch_idx 994 with support = 0.1
# found 51 patterns from 500 trees for batch_idx 994
# start score sort for batch_idx 994 (51) patterns
# start merge rule for batch_idx 994 (51) patterns
# [('capital-gain', True, -0.898), ('education_HS-grad', False, -0.125), ('capital-loss', True, -0.17456)]
# 0.9998615342010524 0.3996568518928492 0.13969612787061175 0.17307038422305338
# merge complete for batch_idx 994 (51) patterns
# start get explainer for batch_idx 994
# Working on CHIRPS for instance 995 of 1000
# as_chirps for batch_idx 995
# start mining for batch_idx 995 with support = 0.1
# found 77 patterns from 236 trees for batch_idx 995
# start score sort for batch_idx 995 (77) patterns
# start merge rule for batch_idx 995 (77) patterns
# [('capital-gain', True, -0.898), ('occupation_Exec-managerial', True, 0.0), ('occupation_Prof-specialty', True, 0.0), ('capital-loss', True, -0.17887)]
# 0.9526023043305523 0.5770919913755098 0.11372364224352151 0.12370925288519943
# merge complete for batch_idx 995 (77) patterns
# start get explainer for batch_idx 995
# as_chirps for batch_idx 996
# start mining for batch_idx 996 with support = 0.1
# found 68 patterns from 386 trees for batch_idx 996
# start score sort for batch_idx 996 (68) patterns
# start merge rule for batch_idx 996 (68) patterns
# [('education_Bachelors', False, -0.125), ('marital-status_Married', False, -0.125)]
# 0.9677215189873418 0.08709263263685976 0.06917989739126408 0.05237981344176032
# merge complete for batch_idx 996 (68) patterns
# start get explainer for batch_idx 996
# as_chirps for batch_idx 997
# start mining for batch_idx 997 with support = 0.1
# found 52 patterns from 500 trees for batch_idx 997
# start score sort for batch_idx 997 (52) patterns
# start merge rule for batch_idx 997 (52) patterns
# [('capital-gain', True, -0.898), ('education_HS-grad', False, -0.125), ('capital-loss', True, -0.17839)]
# 0.9998615342010524 0.3996568518928492 0.2037589592614104 0.20068858285206564
# merge complete for batch_idx 997 (52) patterns
# start get explainer for batch_idx 997
# as_chirps for batch_idx 998
# start mining for batch_idx 998 with support = 0.1
# found 57 patterns from 500 trees for batch_idx 998
# start score sort for batch_idx 998 (57) patterns
# start merge rule for batch_idx 998 (57) patterns
# [('marital-status_Married', True, 0.0), ('capital-gain', True, -0.85832)]
# 0.9972468149427769 0.5089488501125855 0.09777729571014239 0.1822575615840349
# merge complete for batch_idx 998 (57) patterns
# start get explainer for batch_idx 998
# as_chirps for batch_idx 999
# start mining for batch_idx 999 with support = 0.1
# found 47 patterns from 500 trees for batch_idx 999
# start score sort for batch_idx 999 (47) patterns
# start merge rule for batch_idx 999 (47) patterns
# [('capital-gain', True, -0.85817), ('marital-status_Married', True, 0.0)]
# 0.9972468149427769 0.5089488501125855 0.13674671751894082 0.2265060240963855
# merge complete for batch_idx 999 (47) patterns
# start get explainer for batch_idx 999
#     CHIRPS Ready
# 0.0 in: 0.0
# 10.0 in: 2209.1377255916595
# 20.0 in: 2267.3210332393646
# 30.0 in: 1866.9473142623901
# 40.0 in: 1971.931714773178
# 50.0 in: 2240.9921135902405
# 60.0 in: 2215.947911977768
# 70.0 in: 2008.9358358383179
# 80.0 in: 2639.2734265327454
# 90.0 in: 2085.6641302108765
# gs 0.328121999999999 , 4.714 , 1.0 , 0.0003603701591491699
# ls 0.7222230000000008 , 1.36 , 0.7988190874844546 , 2.186338860988617
# an 0.31832300000000074 , 2.659 , 0.7884759957150161 , 18.194019446611403
# lf 0.031551000000000065 , 9.308 , 1.0 , 1.147537350654602
# df 1.0 , 7.912 , 0.8480000000000003 , 0.8624407191276551
# ch 0.38782500000000325 , 2.678 , 0.9831099438158065 , 9.534068024158474
