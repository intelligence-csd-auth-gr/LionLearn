# %% [markdown]
# # This notebook contains the experiments on Adult Census dataset with LionForests

# %%
import sys
cpath = !pwd
sys.path.append(cpath[0][:-18])
sys.path.append('C:\\Users\\iamollas\\Downloads\\LionForests Journal\\')

# %%
import pandas as pd 
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.base import TransformerMixin
from sklearn.preprocessing import MinMaxScaler,StandardScaler, LabelEncoder
from sklearn import preprocessing
from lionforests import LionForests
from datasets.dataset import Dataset
import numpy as np
np.seterr(invalid='ignore')
import warnings
warnings.filterwarnings("ignore")
import time

# %% [markdown]
# Feature Engineering from:
# https://github.com/pooja2512/Adult-Census-Income/blob/master/Adult%20Census%20Income.ipynb. So run and skip the next code block

# %%
adult = Dataset()
X, y, feature_names, class_names, categorical_features = adult.load_adult()

# %% [markdown]
# We declare the name of the categorical features in order LionForests to extract more compact explanations

# %%
from tqdm import tqdm
import time  #10 trees

results = []
iterr = 100
with tqdm(total=4*3*4*24) as pbar:
    for i in [1,5,7,10]:#1,5,7,10
        for j in [10,100,500]:
            for o in ['sqrt','log2', 0.75, None]:#0.75,None
                parameters = [{
                    'max_depth': [i],
                    'max_features': [o],
                    'bootstrap': [True],
                    'min_samples_leaf' : [2],
                    'n_estimators': [j]
                }]
                lf = LionForests(None, False, None, feature_names, class_names, categorical_features)
                lf.train(X, y, params=parameters)
                tlf = 0
                fr = 0
                frr = 0
                pr = 0
                for inde in range(iterr):
                    t_a = time.time()
                    a, b, c, d, e, g, h, _, _ = lf.following_breadcrumbs(X[inde], False, None, None, False)
                    fr = fr + c - e
                    frr = frr + g - h
                    pr = pr + b - d
                    tlf = tlf + time.time() - t_a
                results.append([str(i),str(j),str(o),'NoRed','_','_', tlf/iterr, fr/iterr, pr/iterr, frr/iterr])
                pbar.update(1)
                for k in ['1','2','3','12','13','23','123']:
                        if '1' in k and '2' in k:
                            for ara in ['apriori','fpgrowth']:
                                for cla in ['kmedoids','OPTICS','SC']:
                                    tlf = 0
                                    fr = 0
                                    frr = 0
                                    pr = 0
                                    for inde in range(iterr):
                                        t_a = time.time()
                                        a, b, c, d, e, g, h, _, _ = lf.following_breadcrumbs(X[inde], True, ara, cla, method=k)
                                        fr = fr + c - e
                                        frr = frr + g - h
                                        pr = pr + b - d
                                        tlf = tlf + time.time() - t_a
                                    results.append([str(i),str(j),str(o),k,ara,cla, tlf/iterr, fr/iterr, pr/iterr, frr/iterr])
                                    pbar.update(1)
                        elif '1' in k:
                            for ara in ['apriori','fpgrowth']:
                                tlf = 0
                                fr = 0
                                frr = 0
                                pr = 0
                                for inde in range(iterr):
                                    t_a = time.time()
                                    a, b, c, d, e, g, h, _, _ = lf.following_breadcrumbs(X[inde], True, ara, None, method=k)
                                    fr = fr + c - e
                                    frr = frr + g - h
                                    pr = pr + b - d
                                    tlf = tlf + time.time() - t_a
                                results.append([str(i),str(j),str(o),k,ara,'_', tlf/iterr, fr/iterr, pr/iterr, frr/iterr])
                                pbar.update(1)
                        elif '2' in k:
                            for cla in ['kmedoids','OPTICS','SC']: 
                                tlf = 0
                                fr = 0
                                frr = 0
                                pr = 0
                                for inde in range(iterr):
                                    t_a = time.time()
                                    a, b, c, d, e, g, h, _, _ = lf.following_breadcrumbs(X[inde], True, None, cla, method=k)
                                    fr = fr + c - e
                                    frr = frr + g - h 
                                    pr = pr + b - d
                                    tlf = tlf + time.time() - t_a
                                results.append([str(i),str(j),str(o),k,'_',cla, tlf/iterr, fr/iterr, pr/iterr, frr/iterr])
                                pbar.update(1)
                        else:
                                tlf = 0
                                fr = 0
                                frr = 0
                                pr = 0
                                for inde in range(iterr):
                                    t_a = time.time()
                                    a, b, c, d, e, g, h, _, _ = lf.following_breadcrumbs(X[inde], True, None, None, method=k)
                                    fr = fr + c - e
                                    frr = frr + g - h
                                    pr = pr + b - d
                                    tlf = tlf + time.time() - t_a
                                results.append([str(i),str(j),str(o),k,'_','_', tlf/iterr, fr/iterr, pr/iterr, frr/iterr])
                                pbar.update(1)

# %%
for i in results:
    print(i)
# Out:
# ['1', '10', 'sqrt', 'NoRed', '_', '_', 0.23090699672698975, 0.0, 0.0, 0.0]
# ['1', '10', 'sqrt', '1', 'apriori', '_', 0.48780524492263794, 0.0, 0.0, 0.0]
# ['1', '10', 'sqrt', '1', 'fpgrowth', '_', 0.23108663082122802, 0.0, 0.0, 0.0]
# ['1', '10', 'sqrt', '2', '_', 'kmedoids', 0.22750383853912354, 2.98, 2.98, 2.37]
# ['1', '10', 'sqrt', '2', '_', 'OPTICS', 0.23046306610107423, 0.0, 0.0, 0.0]
# ['1', '10', 'sqrt', '2', '_', 'SC', 0.23546878576278688, 2.25, 2.25, 1.02]
# ['1', '10', 'sqrt', '3', '_', '_', 0.22015636682510376, 1.86, 2.81, 0.69]
# ['1', '10', 'sqrt', '12', 'apriori', 'kmedoids', 0.2335944414138794, 2.98, 2.98, 2.37]
# ['1', '10', 'sqrt', '12', 'apriori', 'OPTICS', 0.2357822585105896, 0.0, 0.0, 0.0]
# ['1', '10', 'sqrt', '12', 'apriori', 'SC', 0.24964271306991578, 2.25, 2.25, 1.02]
# ['1', '10', 'sqrt', '12', 'fpgrowth', 'kmedoids', 0.2332100772857666, 2.98, 2.98, 2.37]
# ['1', '10', 'sqrt', '12', 'fpgrowth', 'OPTICS', 0.23456982135772705, 0.0, 0.0, 0.0]
# ['1', '10', 'sqrt', '12', 'fpgrowth', 'SC', 0.24652837991714477, 2.25, 2.25, 1.02]
# ['1', '10', 'sqrt', '13', 'apriori', '_', 0.23280820608139038, 1.82, 2.81, 0.91]
# ['1', '10', 'sqrt', '13', 'fpgrowth', '_', 0.23239054679870605, 1.86, 2.81, 0.69]
# ['1', '10', 'sqrt', '23', '_', 'kmedoids', 0.22047289371490478, 2.98, 2.98, 2.37]
# ['1', '10', 'sqrt', '23', '_', 'OPTICS', 0.21961534023284912, 1.86, 2.81, 1.7]
# ['1', '10', 'sqrt', '23', '_', 'SC', 0.23504611253738403, 2.25, 2.99, 1.02]
# ['1', '10', 'sqrt', '123', 'apriori', 'kmedoids', 0.2341824960708618, 2.98, 2.98, 2.37]
# ['1', '10', 'sqrt', '123', 'apriori', 'OPTICS', 0.23418567419052125, 0.95, 2.81, 0.93]
# ['1', '10', 'sqrt', '123', 'apriori', 'SC', 0.2494034504890442, 2.25, 2.99, 1.02]
# ['1', '10', 'sqrt', '123', 'fpgrowth', 'kmedoids', 0.23128833770751953, 2.98, 2.98, 2.37]
# ['1', '10', 'sqrt', '123', 'fpgrowth', 'OPTICS', 0.2343652844429016, 1.86, 2.81, 1.7]
# ['1', '10', 'sqrt', '123', 'fpgrowth', 'SC', 0.2485804080963135, 2.25, 2.99, 1.02]
# ['1', '10', 'log2', 'NoRed', '_', '_', 0.21941274881362915, 0.0, 0.0, 0.0]
# ['1', '10', 'log2', '1', 'apriori', '_', 0.23077979803085327, 0.0, 0.0, 0.0]
# ['1', '10', 'log2', '1', 'fpgrowth', '_', 0.2317161774635315, 0.0, 0.0, 0.0]
# ['1', '10', 'log2', '2', '_', 'kmedoids', 0.2195231795310974, 2.98, 2.98, 1.67]
# ['1', '10', 'log2', '2', '_', 'OPTICS', 0.21972395181655885, 0.0, 0.0, 0.0]
# ['1', '10', 'log2', '2', '_', 'SC', 0.235183744430542, 2.25, 2.25, 0.93]
# ['1', '10', 'log2', '3', '_', '_', 0.2197995376586914, 1.86, 2.81, 0.69]
# ['1', '10', 'log2', '12', 'apriori', 'kmedoids', 0.23273522138595581, 2.98, 2.98, 1.67]
# ['1', '10', 'log2', '12', 'apriori', 'OPTICS', 0.23418112754821777, 0.0, 0.0, 0.0]
# ['1', '10', 'log2', '12', 'apriori', 'SC', 0.24943719625473024, 2.25, 2.25, 0.93]
# ['1', '10', 'log2', '12', 'fpgrowth', 'kmedoids', 0.23357794523239137, 2.98, 2.98, 1.67]
# ['1', '10', 'log2', '12', 'fpgrowth', 'OPTICS', 0.23429425239562987, 0.0, 0.0, 0.0]
# ['1', '10', 'log2', '12', 'fpgrowth', 'SC', 0.2481362509727478, 2.25, 2.25, 0.93]
# ['1', '10', 'log2', '13', 'apriori', '_', 0.23332431077957153, 1.82, 2.81, 0.24]
# ['1', '10', 'log2', '13', 'fpgrowth', '_', 0.2321643614768982, 1.86, 2.81, 0.69]
# ['1', '10', 'log2', '23', '_', 'kmedoids', 0.21955806493759156, 2.98, 2.98, 1.67]
# ['1', '10', 'log2', '23', '_', 'OPTICS', 0.21965496301651, 1.86, 2.81, 1.0]
# ['1', '10', 'log2', '23', '_', 'SC', 0.23588080644607545, 2.25, 2.99, 0.93]
# ['1', '10', 'log2', '123', 'apriori', 'kmedoids', 0.23382973432540893, 2.98, 2.98, 1.67]
# ['1', '10', 'log2', '123', 'apriori', 'OPTICS', 0.23454524517059328, 0.95, 2.81, 0.26]
# ['1', '10', 'log2', '123', 'apriori', 'SC', 0.24977747201919556, 2.25, 2.99, 0.93]
# ['1', '10', 'log2', '123', 'fpgrowth', 'kmedoids', 0.23208775281906127, 2.98, 2.98, 1.67]
# ['1', '10', 'log2', '123', 'fpgrowth', 'OPTICS', 0.2341078734397888, 1.86, 2.81, 1.0]
# ['1', '10', 'log2', '123', 'fpgrowth', 'SC', 0.2484851622581482, 2.25, 2.99, 0.93]
# ['1', '10', '0.75', 'NoRed', '_', '_', 0.21964681386947632, 0.0, 0.0, 0.0]
# ['1', '10', '0.75', '1', 'apriori', '_', 0.23294930934906005, 0.0, 0.0, 0.0]
# ['1', '10', '0.75', '1', 'fpgrowth', '_', 0.2330760192871094, 0.0, 0.0, 0.0]
# ['1', '10', '0.75', '2', '_', 'kmedoids', 0.21989925384521483, 0.0, 0.0, 0.0]
# ['1', '10', '0.75', '2', '_', 'OPTICS', 0.22007336378097533, 0.0, 0.0, 0.0]
# ['1', '10', '0.75', '2', '_', 'SC', 0.2364492416381836, 1.4, 2.28, 1.4]
# ['1', '10', '0.75', '3', '_', '_', 0.21966134071350096, 0.97, 2.36, 0.97]
# ['1', '10', '0.75', '12', 'apriori', 'kmedoids', 0.23315492630004883, 0.0, 0.0, 0.0]
# ['1', '10', '0.75', '12', 'apriori', 'OPTICS', 0.2336179256439209, 0.0, 0.0, 0.0]
# ['1', '10', '0.75', '12', 'apriori', 'SC', 0.25012200355529784, 1.4, 2.28, 1.4]
# ['1', '10', '0.75', '12', 'fpgrowth', 'kmedoids', 0.2327372169494629, 0.0, 0.0, 0.0]
# ['1', '10', '0.75', '12', 'fpgrowth', 'OPTICS', 0.2342160415649414, 0.0, 0.0, 0.0]
# ['1', '10', '0.75', '12', 'fpgrowth', 'SC', 0.25041668176651, 1.4, 2.28, 1.4]
# ['1', '10', '0.75', '13', 'apriori', '_', 0.23182412147521972, 0.49, 2.36, 0.49]
# ['1', '10', '0.75', '13', 'fpgrowth', '_', 0.23156577110290527, 0.97, 2.36, 0.97]
# ['1', '10', '0.75', '23', '_', 'kmedoids', 0.2204393982887268, 0.97, 2.36, 0.97]
# ['1', '10', '0.75', '23', '_', 'OPTICS', 0.22099458932876587, 0.92, 2.36, 0.69]
# ['1', '10', '0.75', '23', '_', 'SC', 0.23540517807006836, 1.4, 2.3, 1.4]
# ['1', '10', '0.75', '123', 'apriori', 'kmedoids', 0.2307639718055725, 0.49, 2.36, 0.49]
# ['1', '10', '0.75', '123', 'apriori', 'OPTICS', 0.2342888569831848, 1.38, 2.36, 1.21]
# ['1', '10', '0.75', '123', 'apriori', 'SC', 0.2501621055603027, 1.4, 2.3, 1.4]
# ['1', '10', '0.75', '123', 'fpgrowth', 'kmedoids', 0.2320959186553955, 0.97, 2.36, 0.97]
# ['1', '10', '0.75', '123', 'fpgrowth', 'OPTICS', 0.23490677118301392, 0.92, 2.36, 0.69]
# ['1', '10', '0.75', '123', 'fpgrowth', 'SC', 0.24839919328689575, 1.4, 2.3, 1.4]
# ['1', '10', 'None', 'NoRed', '_', '_', 0.21933670043945314, 0.0, 0.0, 0.0]
# ['1', '10', 'None', '1', 'apriori', '_', 0.23333778381347656, 0.0, 0.0, 0.0]
# ['1', '10', 'None', '1', 'fpgrowth', '_', 0.23232805967330933, 0.0, 0.0, 0.0]
# ['1', '10', 'None', '2', '_', 'kmedoids', 0.21970041275024413, 0.0, 0.0, 0.0]
# ['1', '10', 'None', '2', '_', 'OPTICS', 0.21968884706497194, 0.0, 0.0, 0.0]
# ['1', '10', 'None', '2', '_', 'SC', 0.23548587560653686, 0.0, 1.35, 0.0]
# ['1', '10', 'None', '3', '_', '_', 0.2199705696105957, 0.0, 1.8, 0.0]
# ['1', '10', 'None', '12', 'apriori', 'kmedoids', 0.23434540748596192, 0.0, 0.0, 0.0]
# ['1', '10', 'None', '12', 'apriori', 'OPTICS', 0.23454339742660524, 0.0, 0.0, 0.0]
# ['1', '10', 'None', '12', 'apriori', 'SC', 0.2503464150428772, 0.0, 1.35, 0.0]
# ['1', '10', 'None', '12', 'fpgrowth', 'kmedoids', 0.23138465166091918, 0.0, 0.0, 0.0]
# ['1', '10', 'None', '12', 'fpgrowth', 'OPTICS', 0.2343655490875244, 0.0, 0.0, 0.0]
# ['1', '10', 'None', '12', 'fpgrowth', 'SC', 0.24999834299087526, 0.0, 1.35, 0.0]
# ['1', '10', 'None', '13', 'apriori', '_', 0.23283205509185792, 0.0, 1.8, 0.0]
# ['1', '10', 'None', '13', 'fpgrowth', '_', 0.3494557356834412, 0.0, 1.8, 0.0]
# ['1', '10', 'None', '23', '_', 'kmedoids', 0.2206098771095276, 0.0, 1.8, 0.0]
# ['1', '10', 'None', '23', '_', 'OPTICS', 0.22058342933654784, 0.0, 1.8, 0.0]
# ['1', '10', 'None', '23', '_', 'SC', 0.23555089712142943, 0.0, 1.8, 0.0]
# ['1', '10', 'None', '123', 'apriori', 'kmedoids', 0.23359602451324463, 0.0, 1.8, 0.0]
# ['1', '10', 'None', '123', 'apriori', 'OPTICS', 0.2340216827392578, 0.0, 1.8, 0.0]
# ['1', '10', 'None', '123', 'apriori', 'SC', 0.24922922372817993, 0.0, 1.8, 0.0]
# ['1', '10', 'None', '123', 'fpgrowth', 'kmedoids', 0.23325576782226562, 0.0, 1.8, 0.0]
# ['1', '10', 'None', '123', 'fpgrowth', 'OPTICS', 0.24431084632873534, 0.0, 1.8, 0.0]
# ['1', '10', 'None', '123', 'fpgrowth', 'SC', 0.25512425184249876, 0.0, 1.8, 0.0]
# ['1', '100', 'sqrt', 'NoRed', '_', '_', 0.24856220245361327, 0.0, 0.0, 0.0]
# ['1', '100', 'sqrt', '1', 'apriori', '_', 0.2503119611740112, 0.0, 0.0, 0.0]
# ['1', '100', 'sqrt', '1', 'fpgrowth', '_', 0.25049792051315306, 0.0, 0.0, 0.0]
# ['1', '100', 'sqrt', '2', '_', 'kmedoids', 0.26618668794631956, 5.97, 22.47, 2.17]
# ['1', '100', 'sqrt', '2', '_', 'OPTICS', 0.28345566511154174, 0.0, 0.0, 0.0]
# ['1', '100', 'sqrt', '2', '_', 'SC', 0.3103653883934021, 3.51, 25.48, 2.58]
# ['1', '100', 'sqrt', '3', '_', '_', 0.24969346523284913, 2.2, 31.73, 0.87]
# ['1', '100', 'sqrt', '12', 'apriori', 'kmedoids', 0.27006671667098997, 5.97, 22.47, 2.17]
# ['1', '100', 'sqrt', '12', 'apriori', 'OPTICS', 0.2898995304107666, 0.0, 0.0, 0.0]
# ['1', '100', 'sqrt', '12', 'apriori', 'SC', 0.3387779450416565, 3.51, 25.48, 2.58]
# ['1', '100', 'sqrt', '12', 'fpgrowth', 'kmedoids', 0.27008302688598634, 5.97, 22.47, 2.17]
# ['1', '100', 'sqrt', '12', 'fpgrowth', 'OPTICS', 0.2874826741218567, 0.0, 0.0, 0.0]
# ['1', '100', 'sqrt', '12', 'fpgrowth', 'SC', 0.3428967833518982, 3.51, 25.48, 2.58]
# ['1', '100', 'sqrt', '13', 'apriori', '_', 0.25112659692764283, 2.19, 31.73, 0.12]
# ['1', '100', 'sqrt', '13', 'fpgrowth', '_', 0.25056368589401246, 2.2, 31.73, 0.87]
# ['1', '100', 'sqrt', '23', '_', 'kmedoids', 0.2684886908531189, 6.49, 31.47, 2.59]
# ['1', '100', 'sqrt', '23', '_', 'OPTICS', 0.2853042411804199, 2.71, 31.73, 1.02]
# ['1', '100', 'sqrt', '23', '_', 'SC', 0.33906486988067625, 4.01, 31.26, 2.89]
# ['1', '100', 'sqrt', '123', 'apriori', 'kmedoids', 0.2701794862747192, 6.79, 31.47, 2.5]
# ['1', '100', 'sqrt', '123', 'apriori', 'OPTICS', 0.2904124569892883, 3.52, 31.73, 0.43]
# ['1', '100', 'sqrt', '123', 'apriori', 'SC', 0.3350542974472046, 3.58, 31.26, 2.61]
# ['1', '100', 'sqrt', '123', 'fpgrowth', 'kmedoids', 0.27052809953689577, 6.49, 31.47, 2.59]
# ['1', '100', 'sqrt', '123', 'fpgrowth', 'OPTICS', 0.2905979013442993, 2.71, 31.73, 1.02]
# ['1', '100', 'sqrt', '123', 'fpgrowth', 'SC', 0.3041186761856079, 4.01, 31.26, 2.89]
# ['1', '100', 'log2', 'NoRed', '_', '_', 0.2492450213432312, 0.0, 0.0, 0.0]
# ['1', '100', 'log2', '1', 'apriori', '_', 0.2507085061073303, 0.0, 0.0, 0.0]
# ['1', '100', 'log2', '1', 'fpgrowth', '_', 0.2506774544715881, 0.0, 0.0, 0.0]
# ['1', '100', 'log2', '2', '_', 'kmedoids', 0.2668699312210083, 5.89, 19.87, 2.35]
# ['1', '100', 'log2', '2', '_', 'OPTICS', 0.2861859178543091, 0.0, 0.0, 0.0]
# ['1', '100', 'log2', '2', '_', 'SC', 0.3259381175041199, 4.1, 27.01, 2.49]
# ['1', '100', 'log2', '3', '_', '_', 0.24896042346954345, 5.61, 31.9, 0.25]
# ['1', '100', 'log2', '12', 'apriori', 'kmedoids', 0.28022518396377566, 5.89, 19.87, 2.35]
# ['1', '100', 'log2', '12', 'apriori', 'OPTICS', 0.2960071063041687, 0.0, 0.0, 0.0]
# ['1', '100', 'log2', '12', 'apriori', 'SC', 0.32695880174636843, 4.1, 27.01, 2.49]
# ['1', '100', 'log2', '12', 'fpgrowth', 'kmedoids', 0.27977911233901975, 5.89, 19.87, 2.35]
# ['1', '100', 'log2', '12', 'fpgrowth', 'OPTICS', 0.295558066368103, 0.0, 0.0, 0.0]
# ['1', '100', 'log2', '12', 'fpgrowth', 'SC', 0.34179024457931517, 4.1, 27.01, 2.49]
# ['1', '100', 'log2', '13', 'apriori', '_', 0.25059529304504397, 4.88, 31.9, 0.41]
# ['1', '100', 'log2', '13', 'fpgrowth', '_', 0.2507186007499695, 5.61, 31.9, 0.25]
# ['1', '100', 'log2', '23', '_', 'kmedoids', 0.2675172710418701, 7.62, 32.06, 2.61]
# ['1', '100', 'log2', '23', '_', 'OPTICS', 0.28673027515411376, 4.84, 31.9, 0.96]
# ['1', '100', 'log2', '23', '_', 'SC', 0.3058992862701416, 4.86, 32.01, 2.51]
# ['1', '100', 'log2', '123', 'apriori', 'kmedoids', 0.2804587745666504, 7.42, 32.06, 2.38]
# ['1', '100', 'log2', '123', 'apriori', 'OPTICS', 0.29588847398757934, 5.32, 31.9, 0.27]
# ['1', '100', 'log2', '123', 'apriori', 'SC', 0.335795636177063, 4.8, 32.01, 2.65]
# ['1', '100', 'log2', '123', 'fpgrowth', 'kmedoids', 0.28027404069900513, 7.62, 32.06, 2.61]
# ['1', '100', 'log2', '123', 'fpgrowth', 'OPTICS', 0.295142822265625, 4.84, 31.9, 0.96]
# ['1', '100', 'log2', '123', 'fpgrowth', 'SC', 0.33466503620147703, 4.86, 32.01, 2.51]
# ['1', '100', '0.75', 'NoRed', '_', '_', 0.24970763206481933, 0.0, 0.0, 0.0]
# ['1', '100', '0.75', '1', 'apriori', '_', 0.2491338324546814, 0.0, 0.0, 0.0]
# ['1', '100', '0.75', '1', 'fpgrowth', '_', 0.2501130342483521, 0.0, 0.0, 0.0]
# ['1', '100', '0.75', '2', '_', 'kmedoids', 0.2657917952537537, 0.0, 0.0, 0.0]
# ['1', '100', '0.75', '2', '_', 'OPTICS', 0.28217918634414674, 0.0, 0.0, 0.0]
# ['1', '100', '0.75', '2', '_', 'SC', 0.32563902378082277, 3.34, 21.97, 2.64]
# ['1', '100', '0.75', '3', '_', '_', 0.2482731580734253, 0.0, 27.81, 0.0]
# ['1', '100', '0.75', '12', 'apriori', 'kmedoids', 0.27756743669509887, 0.0, 0.0, 0.0]
# ['1', '100', '0.75', '12', 'apriori', 'OPTICS', 0.439309766292572, 0.0, 0.0, 0.0]
# ['1', '100', '0.75', '12', 'apriori', 'SC', 0.3380050826072693, 3.34, 22.16, 2.64]
# ['1', '100', '0.75', '12', 'fpgrowth', 'kmedoids', 0.2718454098701477, 0.0, 0.0, 0.0]
# ['1', '100', '0.75', '12', 'fpgrowth', 'OPTICS', 0.2848991942405701, 0.0, 0.0, 0.0]
# ['1', '100', '0.75', '12', 'fpgrowth', 'SC', 0.3218433976173401, 3.34, 22.04, 2.64]
# ['1', '100', '0.75', '13', 'apriori', '_', 0.250335054397583, 0.45, 27.81, 0.45]
# ['1', '100', '0.75', '13', 'fpgrowth', '_', 0.24981967926025392, 0.0, 27.81, 0.0]
# ['1', '100', '0.75', '23', '_', 'kmedoids', 0.268094801902771, 0.0, 27.81, 0.0]
# ['1', '100', '0.75', '23', '_', 'OPTICS', 0.2832061958312988, 0.0, 27.81, 0.0]
# ['1', '100', '0.75', '23', '_', 'SC', 0.3168092346191406, 3.34, 28.64, 2.64]
# ['1', '100', '0.75', '123', 'apriori', 'kmedoids', 0.278580915927887, 0.45, 27.81, 0.45]
# ['1', '100', '0.75', '123', 'apriori', 'OPTICS', 0.28522605180740357, 0.45, 27.81, 0.45]
# ['1', '100', '0.75', '123', 'apriori', 'SC', 0.3124707198143005, 3.34, 28.64, 2.64]
# ['1', '100', '0.75', '123', 'fpgrowth', 'kmedoids', 0.27740668058395385, 0.0, 27.81, 0.0]
# ['1', '100', '0.75', '123', 'fpgrowth', 'OPTICS', 0.283414409160614, 0.0, 27.81, 0.0]
# ['1', '100', '0.75', '123', 'fpgrowth', 'SC', 0.3050576376914978, 3.34, 28.64, 2.64]
# ['1', '100', 'None', 'NoRed', '_', '_', 0.2562387919425964, 0.0, 0.0, 0.0]
# ['1', '100', 'None', '1', 'apriori', '_', 0.2498498821258545, 0.0, 0.0, 0.0]
# ['1', '100', 'None', '1', 'fpgrowth', '_', 0.2504387092590332, 0.0, 0.0, 0.0]
# ['1', '100', 'None', '2', '_', 'kmedoids', 0.2678456616401672, 0.0, 0.0, 0.0]
# ['1', '100', 'None', '2', '_', 'OPTICS', 0.29111260652542115, 0.0, 0.0, 0.0]
# ['1', '100', 'None', '2', '_', 'SC', 0.3104268169403076, 0.0, 18.05, 0.0]
# ['1', '100', 'None', '3', '_', '_', 0.25028515577316285, 0.0, 25.65, 0.0]
# ['1', '100', 'None', '12', 'apriori', 'kmedoids', 0.2804697585105896, 0.0, 0.0, 0.0]
# ['1', '100', 'None', '12', 'apriori', 'OPTICS', 0.2833124542236328, 0.0, 0.0, 0.0]
# ['1', '100', 'None', '12', 'apriori', 'SC', 0.3535637855529785, 0.0, 18.05, 0.0]
# ['1', '100', 'None', '12', 'fpgrowth', 'kmedoids', 0.27998464822769165, 0.0, 0.0, 0.0]
# ['1', '100', 'None', '12', 'fpgrowth', 'OPTICS', 0.2843629288673401, 0.0, 0.0, 0.0]
# ['1', '100', 'None', '12', 'fpgrowth', 'SC', 0.33020304441452025, 0.0, 18.05, 0.0]
# ['1', '100', 'None', '13', 'apriori', '_', 0.25047103643417357, 0.0, 25.65, 0.0]
# ['1', '100', 'None', '13', 'fpgrowth', '_', 0.250457706451416, 0.0, 25.65, 0.0]
# ['1', '100', 'None', '23', '_', 'kmedoids', 0.2681658363342285, 0.0, 25.65, 0.0]
# ['1', '100', 'None', '23', '_', 'OPTICS', 0.2821666216850281, 0.0, 25.65, 0.0]
# ['1', '100', 'None', '23', '_', 'SC', 0.3417663836479187, 0.0, 25.65, 0.0]
# ['1', '100', 'None', '123', 'apriori', 'kmedoids', 0.2812696099281311, 0.0, 25.65, 0.0]
# ['1', '100', 'None', '123', 'apriori', 'OPTICS', 0.28776285409927366, 0.0, 25.65, 0.0]
# ['1', '100', 'None', '123', 'apriori', 'SC', 0.32893311500549316, 0.0, 25.65, 0.0]
# ['1', '100', 'None', '123', 'fpgrowth', 'kmedoids', 0.2807865047454834, 0.0, 25.65, 0.0]
# ['1', '100', 'None', '123', 'fpgrowth', 'OPTICS', 0.28516139507293703, 0.0, 25.65, 0.0]
# ['1', '100', 'None', '123', 'fpgrowth', 'SC', 0.34777342319488525, 0.0, 25.65, 0.0]
# ['1', '500', 'sqrt', 'NoRed', '_', '_', 0.3402072381973267, 0.0, 0.0, 0.0]
# ['1', '500', 'sqrt', '1', 'apriori', '_', 0.34472773790359496, 0.0, 0.0, 0.0]
# ['1', '500', 'sqrt', '1', 'fpgrowth', '_', 0.34430336236953735, 0.0, 0.0, 0.0]
# ['1', '500', 'sqrt', '2', '_', 'kmedoids', 1.166379737854004, 18.4, 151.23, 4.29]
# ['1', '500', 'sqrt', '2', '_', 'OPTICS', 1.3033335971832276, 0.0, 0.0, 0.0]
# ['1', '500', 'sqrt', '2', '_', 'SC', 1.4202557969093323, 24.83, 149.24, 4.54]
# ['1', '500', 'sqrt', '3', '_', '_', 0.3470487594604492, 2.17, 160.45, 0.11]
# ['1', '500', 'sqrt', '12', 'apriori', 'kmedoids', 1.1863818860054016, 18.4, 151.23, 4.29]
# ['1', '500', 'sqrt', '12', 'apriori', 'OPTICS', 1.2792464685440064, 0.0, 0.0, 0.0]
# ['1', '500', 'sqrt', '12', 'apriori', 'SC', 1.3454446625709533, 24.83, 149.24, 4.54]
# ['1', '500', 'sqrt', '12', 'fpgrowth', 'kmedoids', 1.151770441532135, 18.4, 151.23, 4.29]
# ['1', '500', 'sqrt', '12', 'fpgrowth', 'OPTICS', 1.27105872631073, 0.0, 0.0, 0.0]
# ['1', '500', 'sqrt', '12', 'fpgrowth', 'SC', 1.4167366456985473, 24.83, 149.24, 4.54]
# ['1', '500', 'sqrt', '13', 'apriori', '_', 0.34631369113922117, 0.59, 160.45, 0.06]
# ['1', '500', 'sqrt', '13', 'fpgrowth', '_', 0.3473479604721069, 2.17, 160.45, 0.11]
# ['1', '500', 'sqrt', '23', '_', 'kmedoids', 1.1678962397575379, 18.4, 159.86, 4.29]
# ['1', '500', 'sqrt', '23', '_', 'OPTICS', 1.2887154269218444, 3.09, 160.45, 0.89]
# ['1', '500', 'sqrt', '23', '_', 'SC', 1.4464929699897766, 24.83, 159.44, 4.54]
# ['1', '500', 'sqrt', '123', 'apriori', 'kmedoids', 1.1837207293510437, 18.41, 159.86, 4.29]
# ['1', '500', 'sqrt', '123', 'apriori', 'OPTICS', 1.493044536113739, 2.8, 160.45, 0.1]
# ['1', '500', 'sqrt', '123', 'apriori', 'SC', 1.4864075469970703, 24.83, 159.44, 4.54]
# ['1', '500', 'sqrt', '123', 'fpgrowth', 'kmedoids', 1.153586347103119, 18.4, 159.86, 4.29]
# ['1', '500', 'sqrt', '123', 'fpgrowth', 'OPTICS', 1.2743150663375855, 3.09, 160.45, 0.89]
# ['1', '500', 'sqrt', '123', 'fpgrowth', 'SC', 1.421389422416687, 24.83, 159.44, 4.54]
# ['1', '500', 'log2', 'NoRed', '_', '_', 0.34095805406570434, 0.0, 0.0, 0.0]
# ['1', '500', 'log2', '1', 'apriori', '_', 0.3442378067970276, 0.0, 0.0, 0.0]
# ['1', '500', 'log2', '1', 'fpgrowth', '_', 0.3438777542114258, 0.0, 0.0, 0.0]
# ['1', '500', 'log2', '2', '_', 'kmedoids', 1.3301581454277038, 19.35, 152.41, 3.52]
# ['1', '500', 'log2', '2', '_', 'OPTICS', 1.4544280171394348, 0.0, 0.0, 0.0]
# ['1', '500', 'log2', '2', '_', 'SC', 1.6173731064796448, 21.11, 154.26, 3.52]
# ['1', '500', 'log2', '3', '_', '_', 0.3469006609916687, 4.34, 161.68, 0.92]
# ['1', '500', 'log2', '12', 'apriori', 'kmedoids', 1.3689429068565369, 19.35, 152.41, 3.52]
# ['1', '500', 'log2', '12', 'apriori', 'OPTICS', 1.4973096895217894, 0.0, 0.0, 0.0]
# ['1', '500', 'log2', '12', 'apriori', 'SC', 1.7290052127838136, 21.11, 154.26, 3.52]
# ['1', '500', 'log2', '12', 'fpgrowth', 'kmedoids', 1.3329035019874573, 19.35, 152.41, 3.52]
# ['1', '500', 'log2', '12', 'fpgrowth', 'OPTICS', 1.5740934300422669, 0.0, 0.0, 0.0]
# ['1', '500', 'log2', '12', 'fpgrowth', 'SC', 1.5672960329055785, 21.11, 154.26, 3.52]
# ['1', '500', 'log2', '13', 'apriori', '_', 0.34560862064361575, 0.51, 161.68, 0.05]
# ['1', '500', 'log2', '13', 'fpgrowth', '_', 0.3673167324066162, 4.34, 161.68, 0.92]
# ['1', '500', 'log2', '23', '_', 'kmedoids', 1.3306916308403016, 19.47, 160.97, 3.52]
# ['1', '500', 'log2', '23', '_', 'OPTICS', 1.4567840909957885, 2.87, 161.68, 0.15]
# ['1', '500', 'log2', '23', '_', 'SC', 1.6292950367927552, 21.19, 161.25, 3.57]
# ['1', '500', 'log2', '123', 'apriori', 'kmedoids', 1.3346310758590698, 19.4, 160.97, 3.57]
# ['1', '500', 'log2', '123', 'apriori', 'OPTICS', 1.4755109810829163, 4.77, 161.68, 0.19]
# ['1', '500', 'log2', '123', 'apriori', 'SC', 1.6401679849624633, 21.24, 161.25, 3.52]
# ['1', '500', 'log2', '123', 'fpgrowth', 'kmedoids', 1.349773395061493, 19.47, 160.97, 3.52]
# ['1', '500', 'log2', '123', 'fpgrowth', 'OPTICS', 1.474557065963745, 2.87, 161.68, 0.15]
# ['1', '500', 'log2', '123', 'fpgrowth', 'SC', 1.5577346062660218, 21.19, 161.25, 3.57]
# ['1', '500', '0.75', 'NoRed', '_', '_', 0.33598067283630373, 0.0, 0.0, 0.0]
# ['1', '500', '0.75', '1', 'apriori', '_', 0.3422646164894104, 0.0, 0.0, 0.0]
# ['1', '500', '0.75', '1', 'fpgrowth', '_', 0.3420890784263611, 0.0, 0.0, 0.0]
# ['1', '500', '0.75', '2', '_', 'kmedoids', 1.1162917637825012, 0.0, 0.0, 0.0]
# ['1', '500', '0.75', '2', '_', 'OPTICS', 0.9897531485557556, 0.0, 0.0, 0.0]
# ['1', '500', '0.75', '2', '_', 'SC', 16.593341195583342, 0.34, 35.36, 0.33]
# ['1', '500', '0.75', '3', '_', '_', 0.5247804880142212, 0.0, 143.03, 0.0]
# ['1', '500', '0.75', '12', 'apriori', 'kmedoids', 0.9552946662902833, 0.0, 0.0, 0.0]
# ['1', '500', '0.75', '12', 'apriori', 'OPTICS', 0.997206335067749, 0.0, 0.0, 0.0]
# ['1', '500', '0.75', '12', 'apriori', 'SC', 16.7878838801384, 0.34, 35.36, 0.33]
# ['1', '500', '0.75', '12', 'fpgrowth', 'kmedoids', 0.9573594617843628, 0.0, 0.0, 0.0]
# ['1', '500', '0.75', '12', 'fpgrowth', 'OPTICS', 1.0017241024971009, 0.0, 0.0, 0.0]
# ['1', '500', '0.75', '12', 'fpgrowth', 'SC', 16.708858134746553, 0.34, 35.36, 0.33]
# ['1', '500', '0.75', '13', 'apriori', '_', 0.3435568976402283, 0.0, 143.03, 0.0]
# ['1', '500', '0.75', '13', 'fpgrowth', '_', 0.34408969163894654, 0.0, 143.03, 0.0]
# ['1', '500', '0.75', '23', '_', 'kmedoids', 0.9482918524742127, 0.0, 143.03, 0.0]
# ['1', '500', '0.75', '23', '_', 'OPTICS', 0.9941479253768921, 0.0, 143.03, 0.0]
# ['1', '500', '0.75', '23', '_', 'SC', 16.68228565454483, 0.34, 143.25, 0.33]
# ['1', '500', '0.75', '123', 'apriori', 'kmedoids', 0.9604422545433045, 0.0, 143.03, 0.0]
# ['1', '500', '0.75', '123', 'apriori', 'OPTICS', 1.0057587003707886, 0.0, 143.03, 0.0]
# ['1', '500', '0.75', '123', 'apriori', 'SC', 17.924569742679594, 0.34, 143.25, 0.33]
# ['1', '500', '0.75', '123', 'fpgrowth', 'kmedoids', 0.9647660350799561, 0.0, 143.03, 0.0]
# ['1', '500', '0.75', '123', 'fpgrowth', 'OPTICS', 1.008953561782837, 0.0, 143.03, 0.0]
# ['1', '500', '0.75', '123', 'fpgrowth', 'SC', 17.583366453647614, 0.34, 143.25, 0.33]
# ['1', '500', 'None', 'NoRed', '_', '_', 0.354539954662323, 0.0, 0.0, 0.0]
# ['1', '500', 'None', '1', 'apriori', '_', 0.36094184398651125, 0.0, 0.0, 0.0]
# ['1', '500', 'None', '1', 'fpgrowth', '_', 0.3604606533050537, 0.0, 0.0, 0.0]
# ['1', '500', 'None', '2', '_', 'kmedoids', 1.1926612544059754, 0.0, 0.0, 0.0]
# ['1', '500', 'None', '2', '_', 'OPTICS', 1.203746600151062, 0.0, 0.0, 0.0]
# ['1', '500', 'None', '2', '_', 'SC', 1.2298799514770509, 0.0, 88.6, 0.0]
# ['1', '500', 'None', '3', '_', '_', 0.3595618200302124, 0.0, 131.35, 0.0]
# ['1', '500', 'None', '12', 'apriori', 'kmedoids', 1.2113236594200134, 0.0, 0.0, 0.0]
# ['1', '500', 'None', '12', 'apriori', 'OPTICS', 1.1625524473190307, 0.0, 0.0, 0.0]
# ['1', '500', 'None', '12', 'apriori', 'SC', 1.3508907389640807, 0.0, 88.6, 0.0]
# ['1', '500', 'None', '12', 'fpgrowth', 'kmedoids', 1.203517909049988, 0.0, 0.0, 0.0]
# ['1', '500', 'None', '12', 'fpgrowth', 'OPTICS', 1.1712034463882446, 0.0, 0.0, 0.0]
# ['1', '500', 'None', '12', 'fpgrowth', 'SC', 1.2633659744262695, 0.0, 88.6, 0.0]
# ['1', '500', 'None', '13', 'apriori', '_', 0.36263869762420653, 0.0, 131.35, 0.0]
# ['1', '500', 'None', '13', 'fpgrowth', '_', 0.48855239152908325, 0.0, 131.35, 0.0]
# ['1', '500', 'None', '23', '_', 'kmedoids', 1.1858010745048524, 0.0, 131.35, 0.0]
# ['1', '500', 'None', '23', '_', 'OPTICS', 1.167367970943451, 0.0, 131.35, 0.0]
# ['1', '500', 'None', '23', '_', 'SC', 1.237466917037964, 0.0, 131.35, 0.0]
# ['1', '500', 'None', '123', 'apriori', 'kmedoids', 1.2025391554832459, 0.0, 131.35, 0.0]
# ['1', '500', 'None', '123', 'apriori', 'OPTICS', 1.1755782771110534, 0.0, 131.35, 0.0]
# ['1', '500', 'None', '123', 'apriori', 'SC', 1.246528754234314, 0.0, 131.35, 0.0]
# ['1', '500', 'None', '123', 'fpgrowth', 'kmedoids', 1.2156553316116332, 0.0, 131.35, 0.0]
# ['1', '500', 'None', '123', 'fpgrowth', 'OPTICS', 1.1812410855293274, 0.0, 131.35, 0.0]
# ['1', '500', 'None', '123', 'fpgrowth', 'SC', 1.2771274709701539, 0.0, 131.35, 0.0]
# ['5', '10', 'sqrt', 'NoRed', '_', '_', 0.21937313795089722, 0.0, 0.0, 0.0]
# ['5', '10', 'sqrt', '1', 'apriori', '_', 0.2338457489013672, 3.16, 2.13, 0.94]
# ['5', '10', 'sqrt', '1', 'fpgrowth', '_', 0.23315002918243408, 3.9, 2.2, 1.07]
# ['5', '10', 'sqrt', '2', '_', 'kmedoids', 0.2195304226875305, 2.81, 1.86, 0.73]
# ['5', '10', 'sqrt', '2', '_', 'OPTICS', 0.22218907356262207, 0.0, 0.0, 0.0]
# ['5', '10', 'sqrt', '2', '_', 'SC', 0.2392127013206482, 2.54, 1.8, 0.63]
# ['5', '10', 'sqrt', '3', '_', '_', 0.2197665739059448, 2.68, 2.14, 0.96]
# ['5', '10', 'sqrt', '12', 'apriori', 'kmedoids', 0.2336969780921936, 3.25, 2.19, 0.95]
# ['5', '10', 'sqrt', '12', 'apriori', 'OPTICS', 0.23568164587020873, 3.16, 2.13, 0.94]
# ['5', '10', 'sqrt', '12', 'apriori', 'SC', 0.24340916872024537, 3.21, 2.15, 0.95]
# ['5', '10', 'sqrt', '12', 'fpgrowth', 'kmedoids', 0.23279702425003052, 3.91, 2.25, 1.08]
# ['5', '10', 'sqrt', '12', 'fpgrowth', 'OPTICS', 0.23329165935516358, 3.9, 2.2, 1.07]
# ['5', '10', 'sqrt', '12', 'fpgrowth', 'SC', 0.2392850375175476, 4.11, 2.26, 1.11]
# ['5', '10', 'sqrt', '13', 'apriori', '_', 0.23382457733154297, 3.17, 2.17, 0.94]
# ['5', '10', 'sqrt', '13', 'fpgrowth', '_', 0.23311018705368042, 3.9, 2.21, 1.07]
# ['5', '10', 'sqrt', '23', '_', 'kmedoids', 0.2197530436515808, 3.16, 2.15, 0.91]
# ['5', '10', 'sqrt', '23', '_', 'OPTICS', 0.22248455286026, 2.1, 2.14, 0.69]
# ['5', '10', 'sqrt', '23', '_', 'SC', 0.2393356204032898, 2.74, 2.14, 0.74]
# ['5', '10', 'sqrt', '123', 'apriori', 'kmedoids', 0.2343109655380249, 3.25, 2.19, 0.95]
# ['5', '10', 'sqrt', '123', 'apriori', 'OPTICS', 0.2357049512863159, 3.17, 2.17, 0.94]
# ['5', '10', 'sqrt', '123', 'apriori', 'SC', 0.24473119020462036, 3.21, 2.15, 0.95]
# ['5', '10', 'sqrt', '123', 'fpgrowth', 'kmedoids', 0.23336586236953735, 3.91, 2.25, 1.08]
# ['5', '10', 'sqrt', '123', 'fpgrowth', 'OPTICS', 0.23289437770843505, 3.91, 2.21, 1.08]
# ['5', '10', 'sqrt', '123', 'fpgrowth', 'SC', 0.23926807641983033, 4.11, 2.26, 1.11]
# ['5', '10', 'log2', 'NoRed', '_', '_', 0.21928818702697753, 0.0, 0.0, 0.0]
# ['5', '10', 'log2', '1', 'apriori', '_', 0.2385388970375061, 5.62, 2.43, 1.9]
# ['5', '10', 'log2', '1', 'fpgrowth', '_', 0.23530848503112792, 4.96, 2.52, 1.24]
# ['5', '10', 'log2', '2', '_', 'kmedoids', 0.2193223452568054, 5.26, 2.22, 1.26]
# ['5', '10', 'log2', '2', '_', 'OPTICS', 0.2216123867034912, 0.0, 0.0, 0.0]
# ['5', '10', 'log2', '2', '_', 'SC', 0.24449677467346193, 4.93, 1.94, 1.16]
# ['5', '10', 'log2', '3', '_', '_', 0.21910938739776611, 4.7, 2.49, 0.81]
# ['5', '10', 'log2', '12', 'apriori', 'kmedoids', 1.0313551235198974, 5.93, 2.54, 1.99]
# ['5', '10', 'log2', '12', 'apriori', 'OPTICS', 0.24275051832199096, 5.62, 2.43, 1.9]
# ['5', '10', 'log2', '12', 'apriori', 'SC', 0.25418365716934205, 5.81, 2.5, 1.94]
# ['5', '10', 'log2', '12', 'fpgrowth', 'kmedoids', 0.23629865646362305, 5.29, 2.64, 1.34]
# ['5', '10', 'log2', '12', 'fpgrowth', 'OPTICS', 0.2357309317588806, 4.96, 2.52, 1.24]
# ['5', '10', 'log2', '12', 'fpgrowth', 'SC', 0.24566619634628295, 5.15, 2.59, 1.28]
# ['5', '10', 'log2', '13', 'apriori', '_', 0.23666609048843384, 5.74, 2.49, 1.93]
# ['5', '10', 'log2', '13', 'fpgrowth', '_', 0.23639872074127197, 5.06, 2.56, 1.26]
# ['5', '10', 'log2', '23', '_', 'kmedoids', 0.2195132303237915, 5.65, 2.39, 1.36]
# ['5', '10', 'log2', '23', '_', 'OPTICS', 0.22332942724227905, 5.13, 2.49, 1.49]
# ['5', '10', 'log2', '23', '_', 'SC', 0.2481515073776245, 5.69, 2.34, 1.3]
# ['5', '10', 'log2', '123', 'apriori', 'kmedoids', 0.23974969387054443, 5.93, 2.54, 1.99]
# ['5', '10', 'log2', '123', 'apriori', 'OPTICS', 0.24411532163619995, 5.74, 2.49, 1.93]
# ['5', '10', 'log2', '123', 'apriori', 'SC', 0.25686848402023316, 5.81, 2.5, 1.94]
# ['5', '10', 'log2', '123', 'fpgrowth', 'kmedoids', 0.2353222632408142, 5.29, 2.64, 1.34]
# ['5', '10', 'log2', '123', 'fpgrowth', 'OPTICS', 0.2362054967880249, 5.01, 2.56, 1.24]
# ['5', '10', 'log2', '123', 'fpgrowth', 'SC', 0.24630896806716918, 5.15, 2.59, 1.28]
# ['5', '10', '0.75', 'NoRed', '_', '_', 0.2196051812171936, 0.0, 0.0, 0.0]
# ['5', '10', '0.75', '1', 'apriori', '_', 0.23127557277679445, 2.05, 2.1, 0.53]
# ['5', '10', '0.75', '1', 'fpgrowth', '_', 0.23039743185043335, 2.16, 2.2, 0.41]
# ['5', '10', '0.75', '2', '_', 'kmedoids', 0.22025371551513673, 1.58, 2.21, 0.53]
# ['5', '10', '0.75', '2', '_', 'OPTICS', 0.22384945869445802, 0.02, 0.08, 0.0]
# ['5', '10', '0.75', '2', '_', 'SC', 0.2397569537162781, 1.49, 1.99, 0.44]
# ['5', '10', '0.75', '3', '_', '_', 0.21947514057159423, 1.34, 2.46, 0.27]
# ['5', '10', '0.75', '12', 'apriori', 'kmedoids', 0.2312980055809021, 2.08, 2.48, 0.53]
# ['5', '10', '0.75', '12', 'apriori', 'OPTICS', 0.23137161016464233, 2.05, 2.1, 0.53]
# ['5', '10', '0.75', '12', 'apriori', 'SC', 0.23770642757415772, 2.25, 2.49, 0.54]
# ['5', '10', '0.75', '12', 'fpgrowth', 'kmedoids', 0.23043160200119017, 2.32, 2.51, 0.57]
# ['5', '10', '0.75', '12', 'fpgrowth', 'OPTICS', 0.2312455415725708, 2.16, 2.2, 0.41]
# ['5', '10', '0.75', '12', 'fpgrowth', 'SC', 0.23649791717529298, 2.32, 2.54, 0.42]
# ['5', '10', '0.75', '13', 'apriori', '_', 0.23089423656463623, 2.07, 2.49, 0.54]
# ['5', '10', '0.75', '13', 'fpgrowth', '_', 0.2308446192741394, 2.32, 2.51, 0.41]
# ['5', '10', '0.75', '23', '_', 'kmedoids', 0.21980318546295166, 1.84, 2.5, 0.69]
# ['5', '10', '0.75', '23', '_', 'OPTICS', 0.22467124700546265, 0.68, 2.46, 0.23]
# ['5', '10', '0.75', '23', '_', 'SC', 0.24076175928115845, 1.52, 2.49, 0.44]
# ['5', '10', '0.75', '123', 'apriori', 'kmedoids', 0.23099027156829835, 2.08, 2.49, 0.53]
# ['5', '10', '0.75', '123', 'apriori', 'OPTICS', 0.23156409502029418, 2.08, 2.49, 0.53]
# ['5', '10', '0.75', '123', 'apriori', 'SC', 0.237883460521698, 2.25, 2.49, 0.54]
# ['5', '10', '0.75', '123', 'fpgrowth', 'kmedoids', 0.23025104761123658, 2.32, 2.51, 0.57]
# ['5', '10', '0.75', '123', 'fpgrowth', 'OPTICS', 0.2305631971359253, 2.16, 2.51, 0.41]
# ['5', '10', '0.75', '123', 'fpgrowth', 'SC', 0.2371305561065674, 2.32, 2.54, 0.42]
# ['5', '10', 'None', 'NoRed', '_', '_', 0.2194640588760376, 0.0, 0.0, 0.0]
# ['5', '10', 'None', '1', 'apriori', '_', 0.2342064666748047, 0.83, 1.14, 0.11]
# ['5', '10', 'None', '1', 'fpgrowth', '_', 0.23339590072631836, 0.77, 1.5, 0.06]
# ['5', '10', 'None', '2', '_', 'kmedoids', 0.2202354907989502, 0.6, 2.32, 0.08]
# ['5', '10', 'None', '2', '_', 'OPTICS', 0.22616056442260743, 0.0, 0.12, 0.0]
# ['5', '10', 'None', '2', '_', 'SC', 0.24620946884155273, 0.89, 2.4, 0.07]
# ['5', '10', 'None', '3', '_', '_', 0.21943227529525758, 0.47, 2.66, 0.01]
# ['5', '10', 'None', '12', 'apriori', 'kmedoids', 0.23412041902542113, 0.83, 2.29, 0.11]
# ['5', '10', 'None', '12', 'apriori', 'OPTICS', 0.23446087598800658, 0.83, 1.14, 0.11]
# ['5', '10', 'None', '12', 'apriori', 'SC', 0.24726776599884034, 0.85, 2.3, 0.11]
# ['5', '10', 'None', '12', 'fpgrowth', 'kmedoids', 0.2333820343017578, 0.97, 2.49, 0.06]
# ['5', '10', 'None', '12', 'fpgrowth', 'OPTICS', 0.23322111129760742, 0.77, 1.5, 0.06]
# ['5', '10', 'None', '12', 'fpgrowth', 'SC', 0.24664849281311035, 0.79, 2.46, 0.06]
# ['5', '10', 'None', '13', 'apriori', '_', 0.23359113931655884, 0.83, 2.64, 0.11]
# ['5', '10', 'None', '13', 'fpgrowth', '_', 0.23366297245025636, 1.01, 2.64, 0.06]
# ['5', '10', 'None', '23', '_', 'kmedoids', 0.2201218342781067, 0.64, 2.64, 0.08]
# ['5', '10', 'None', '23', '_', 'OPTICS', 0.22606459140777588, 0.1, 2.66, 0.05]
# ['5', '10', 'None', '23', '_', 'SC', 0.24671531915664674, 0.89, 2.65, 0.07]
# ['5', '10', 'None', '123', 'apriori', 'kmedoids', 0.234320011138916, 0.83, 2.65, 0.11]
# ['5', '10', 'None', '123', 'apriori', 'OPTICS', 0.233964524269104, 0.83, 2.64, 0.11]
# ['5', '10', 'None', '123', 'apriori', 'SC', 0.2474286961555481, 0.85, 2.68, 0.11]
# ['5', '10', 'None', '123', 'fpgrowth', 'kmedoids', 0.2331412887573242, 0.99, 2.65, 0.06]
# ['5', '10', 'None', '123', 'fpgrowth', 'OPTICS', 0.23334343433380128, 0.83, 2.64, 0.12]
# ['5', '10', 'None', '123', 'fpgrowth', 'SC', 0.24665989637374877, 0.79, 2.64, 0.06]
# ['5', '100', 'sqrt', 'NoRed', '_', '_', 0.24731961965560914, 0.0, 0.0, 0.0]
# ['5', '100', 'sqrt', '1', 'apriori', '_', 0.25480486392974855, 0.0, 0.0, 0.0]
# ['5', '100', 'sqrt', '1', 'fpgrowth', '_', 0.25372020959854125, 0.0, 0.0, 0.0]
# ['5', '100', 'sqrt', '2', '_', 'kmedoids', 0.32833738803863527, 3.55, 20.67, 0.39]
# ['5', '100', 'sqrt', '2', '_', 'OPTICS', 0.3414243412017822, 0.0, 0.0, 0.0]
# ['5', '100', 'sqrt', '2', '_', 'SC', 0.3565683650970459, 3.42, 19.89, 0.3]
# ['5', '100', 'sqrt', '3', '_', '_', 0.24830146312713622, 3.86, 24.75, 0.29]
# ['5', '100', 'sqrt', '12', 'apriori', 'kmedoids', 0.3408024549484253, 3.55, 20.67, 0.39]
# ['5', '100', 'sqrt', '12', 'apriori', 'OPTICS', 0.3507424283027649, 0.0, 0.0, 0.0]
# ['5', '100', 'sqrt', '12', 'apriori', 'SC', 0.3654041409492493, 3.42, 19.89, 0.3]
# ['5', '100', 'sqrt', '12', 'fpgrowth', 'kmedoids', 0.3363135528564453, 3.55, 20.67, 0.39]
# ['5', '100', 'sqrt', '12', 'fpgrowth', 'OPTICS', 0.351687924861908, 0.0, 0.0, 0.0]
# ['5', '100', 'sqrt', '12', 'fpgrowth', 'SC', 0.3882180309295654, 3.42, 19.89, 0.3]
# ['5', '100', 'sqrt', '13', 'apriori', '_', 0.25608845472335817, 4.04, 24.75, 0.34]
# ['5', '100', 'sqrt', '13', 'fpgrowth', '_', 0.2554163122177124, 3.86, 24.75, 0.29]
# ['5', '100', 'sqrt', '23', '_', 'kmedoids', 0.33037988901138304, 4.25, 24.88, 0.47]
# ['5', '100', 'sqrt', '23', '_', 'OPTICS', 0.46682358026504517, 3.83, 24.75, 0.49]
# ['5', '100', 'sqrt', '23', '_', 'SC', 0.35297694683074954, 4.57, 24.99, 0.42]
# ['5', '100', 'sqrt', '123', 'apriori', 'kmedoids', 0.336270215511322, 4.23, 24.88, 0.46]
# ['5', '100', 'sqrt', '123', 'apriori', 'OPTICS', 0.3520862293243408, 4.5, 24.75, 0.38]
# ['5', '100', 'sqrt', '123', 'apriori', 'SC', 0.4178602981567383, 4.32, 24.99, 0.37]
# ['5', '100', 'sqrt', '123', 'fpgrowth', 'kmedoids', 0.338271427154541, 4.25, 24.88, 0.47]
# ['5', '100', 'sqrt', '123', 'fpgrowth', 'OPTICS', 0.35109970092773435, 3.83, 24.75, 0.49]
# ['5', '100', 'sqrt', '123', 'fpgrowth', 'SC', 0.36693663597106935, 4.57, 24.99, 0.42]
# ['5', '100', 'log2', 'NoRed', '_', '_', 0.24913429021835326, 0.0, 0.0, 0.0]
# ['5', '100', 'log2', '1', 'apriori', '_', 0.24958997011184691, 0.0, 0.0, 0.0]
# ['5', '100', 'log2', '1', 'fpgrowth', '_', 0.2515185284614563, 0.0, 0.0, 0.0]
# ['5', '100', 'log2', '2', '_', 'kmedoids', 0.3381177496910095, 3.11, 21.09, 0.1]
# ['5', '100', 'log2', '2', '_', 'OPTICS', 0.3547947382926941, 0.0, 0.0, 0.0]
# ['5', '100', 'log2', '2', '_', 'SC', 0.37176788806915284, 2.72, 20.2, 0.03]
# ['5', '100', 'log2', '3', '_', '_', 0.24802638053894044, 4.01, 25.18, 0.18]
# ['5', '100', 'log2', '12', 'apriori', 'kmedoids', 0.3464861035346985, 3.11, 21.09, 0.1]
# ['5', '100', 'log2', '12', 'apriori', 'OPTICS', 0.3599035573005676, 0.0, 0.0, 0.0]
# ['5', '100', 'log2', '12', 'apriori', 'SC', 0.3752185082435608, 2.72, 20.2, 0.03]
# ['5', '100', 'log2', '12', 'fpgrowth', 'kmedoids', 0.346872456073761, 3.11, 21.09, 0.1]
# ['5', '100', 'log2', '12', 'fpgrowth', 'OPTICS', 0.3586022424697876, 0.0, 0.0, 0.0]
# ['5', '100', 'log2', '12', 'fpgrowth', 'SC', 0.37513896465301516, 2.72, 20.2, 0.03]
# ['5', '100', 'log2', '13', 'apriori', '_', 0.2516040587425232, 4.3, 25.18, 0.06]
# ['5', '100', 'log2', '13', 'fpgrowth', '_', 0.2505516290664673, 4.01, 25.18, 0.18]
# ['5', '100', 'log2', '23', '_', 'kmedoids', 0.3404230570793152, 4.05, 25.39, 0.15]
# ['5', '100', 'log2', '23', '_', 'OPTICS', 0.35472784519195555, 4.24, 25.18, 0.05]
# ['5', '100', 'log2', '23', '_', 'SC', 0.3763045954704285, 3.81, 25.62, 0.04]
# ['5', '100', 'log2', '123', 'apriori', 'kmedoids', 0.34696617364883425, 3.98, 25.39, 0.14]
# ['5', '100', 'log2', '123', 'apriori', 'OPTICS', 0.3594509744644165, 3.69, 25.18, 0.02]
# ['5', '100', 'log2', '123', 'apriori', 'SC', 0.3755156350135803, 3.78, 25.62, 0.05]
# ['5', '100', 'log2', '123', 'fpgrowth', 'kmedoids', 0.34597038745880127, 4.05, 25.39, 0.15]
# ['5', '100', 'log2', '123', 'fpgrowth', 'OPTICS', 0.3600534772872925, 4.24, 25.18, 0.05]
# ['5', '100', 'log2', '123', 'fpgrowth', 'SC', 0.37620853900909423, 3.81, 25.62, 0.04]
# ['5', '100', '0.75', 'NoRed', '_', '_', 0.24806700944900512, 0.0, 0.0, 0.0]
# ['5', '100', '0.75', '1', 'apriori', '_', 0.25955063104629517, 4.96, 23.09, 1.16]
# ['5', '100', '0.75', '1', 'fpgrowth', '_', 0.2567004227638245, 4.88, 22.61, 1.13]
# ['5', '100', '0.75', '2', '_', 'kmedoids', 0.3249225664138794, 1.76, 25.11, 0.57]
# ['5', '100', '0.75', '2', '_', 'OPTICS', 0.33873801946640014, 0.53, 11.18, 0.15]
# ['5', '100', '0.75', '2', '_', 'SC', 0.3450933814048767, 2.85, 26.58, 0.68]
# ['5', '100', '0.75', '3', '_', '_', 0.2479876446723938, 0.78, 29.72, 0.12]
# ['5', '100', '0.75', '12', 'apriori', 'kmedoids', 0.29114562034606933, 5.14, 27.7, 1.16]
# ['5', '100', '0.75', '12', 'apriori', 'OPTICS', 0.3011739706993103, 5.02, 24.08, 1.18]
# ['5', '100', '0.75', '12', 'apriori', 'SC', 0.3402110004425049, 5.08, 28.1, 1.16]
# ['5', '100', '0.75', '12', 'fpgrowth', 'kmedoids', 0.2905694770812988, 5.11, 27.58, 1.15]
# ['5', '100', '0.75', '12', 'fpgrowth', 'OPTICS', 0.2991099715232849, 4.96, 23.99, 1.16]
# ['5', '100', '0.75', '12', 'fpgrowth', 'SC', 0.3100074076652527, 5.03, 27.99, 1.13]
# ['5', '100', '0.75', '13', 'apriori', '_', 0.2594436073303223, 5.08, 29.91, 1.17]
# ['5', '100', '0.75', '13', 'fpgrowth', '_', 0.25658090829849245, 4.99, 29.86, 1.14]
# ['5', '100', '0.75', '23', '_', 'kmedoids', 0.32587279558181764, 1.88, 29.94, 0.6]
# ['5', '100', '0.75', '23', '_', 'OPTICS', 0.3372387599945068, 1.02, 29.96, 0.3]
# ['5', '100', '0.75', '23', '_', 'SC', 0.3780810856819153, 2.98, 29.9, 0.73]
# ['5', '100', '0.75', '123', 'apriori', 'kmedoids', 0.29259843587875367, 5.14, 29.93, 1.16]
# ['5', '100', '0.75', '123', 'apriori', 'OPTICS', 0.3000485968589783, 5.04, 29.86, 1.18]
# ['5', '100', '0.75', '123', 'apriori', 'SC', 0.3121122574806213, 5.08, 30.03, 1.16]
# ['5', '100', '0.75', '123', 'fpgrowth', 'kmedoids', 0.2912981748580933, 5.13, 29.87, 1.15]
# ['5', '100', '0.75', '123', 'fpgrowth', 'OPTICS', 0.29937158823013305, 4.97, 29.92, 1.17]
# ['5', '100', '0.75', '123', 'fpgrowth', 'SC', 0.8433486914634705, 5.04, 29.97, 1.14]
# ['5', '100', 'None', 'NoRed', '_', '_', 0.24943694829940796, 0.0, 0.0, 0.0]
# ['5', '100', 'None', '1', 'apriori', '_', 0.2619342398643494, 1.69, 17.8, 0.52]
# ['5', '100', 'None', '1', 'fpgrowth', '_', 0.25498247385025025, 1.61, 14.48, 0.29]
# ['5', '100', 'None', '2', '_', 'kmedoids', 0.3409429717063904, 0.76, 21.34, 0.33]
# ['5', '100', 'None', '2', '_', 'OPTICS', 0.3564628648757935, 0.28, 9.43, 0.13]
# ['5', '100', 'None', '2', '_', 'SC', 0.3658110427856445, 2.1, 23.92, 0.58]
# ['5', '100', 'None', '3', '_', '_', 0.24859538793563843, 0.91, 31.26, 0.09]
# ['5', '100', 'None', '12', 'apriori', 'kmedoids', 0.3217523694038391, 1.9, 25.75, 0.71]
# ['5', '100', 'None', '12', 'apriori', 'OPTICS', 0.3354414176940918, 1.93, 20.16, 0.65]
# ['5', '100', 'None', '12', 'apriori', 'SC', 0.34530054569244384, 2.27, 27.4, 0.89]
# ['5', '100', 'None', '12', 'fpgrowth', 'kmedoids', 0.321694450378418, 1.9, 25.89, 0.52]
# ['5', '100', 'None', '12', 'fpgrowth', 'OPTICS', 0.336140513420105, 1.87, 16.44, 0.42]
# ['5', '100', 'None', '12', 'fpgrowth', 'SC', 0.35682403087615966, 2.27, 26.74, 0.7]
# ['5', '100', 'None', '13', 'apriori', '_', 0.2625454616546631, 1.77, 31.08, 0.56]
# ['5', '100', 'None', '13', 'fpgrowth', '_', 0.2550566029548645, 1.85, 31.3, 0.32]
# ['5', '100', 'None', '23', '_', 'kmedoids', 0.3400310969352722, 0.95, 31.04, 0.34]
# ['5', '100', 'None', '23', '_', 'OPTICS', 0.3594996523857117, 1.03, 31.28, 0.18]
# ['5', '100', 'None', '23', '_', 'SC', 0.4210695266723633, 2.1, 31.32, 0.58]
# ['5', '100', 'None', '123', 'apriori', 'kmedoids', 0.32313205480575563, 1.92, 31.11, 0.71]
# ['5', '100', 'None', '123', 'apriori', 'OPTICS', 0.33601205825805663, 1.97, 31.11, 0.66]
# ['5', '100', 'None', '123', 'apriori', 'SC', 0.3462917613983154, 2.27, 31.14, 0.89]
# ['5', '100', 'None', '123', 'fpgrowth', 'kmedoids', 0.3223401403427124, 1.9, 31.32, 0.52]
# ['5', '100', 'None', '123', 'fpgrowth', 'OPTICS', 0.33613081932067873, 1.97, 31.33, 0.44]
# ['5', '100', 'None', '123', 'fpgrowth', 'SC', 0.3383136987686157, 2.27, 31.35, 0.7]
# ['5', '500', 'sqrt', 'NoRed', '_', '_', 0.33354451656341555, 0.0, 0.0, 0.0]
# ['5', '500', 'sqrt', '1', 'apriori', '_', 0.3456509900093079, 0.0, 0.0, 0.0]
# ['5', '500', 'sqrt', '1', 'fpgrowth', '_', 0.3471895384788513, 0.0, 0.0, 0.0]
# ['5', '500', 'sqrt', '2', '_', 'kmedoids', 2.6378716111183165, 4.1, 120.21, 0.06]
# ['5', '500', 'sqrt', '2', '_', 'OPTICS', 2.7062212872505187, 0.0, 0.0, 0.0]
# ['5', '500', 'sqrt', '2', '_', 'SC', 2.9672251248359682, 7.07, 120.09, 0.78]
# ['5', '500', 'sqrt', '3', '_', '_', 0.8248480439186097, 3.54, 124.54, 0.01]
# ['5', '500', 'sqrt', '12', 'apriori', 'kmedoids', 3.009661695957184, 4.1, 120.21, 0.06]
# ['5', '500', 'sqrt', '12', 'apriori', 'OPTICS', 3.11926730632782, 0.0, 0.0, 0.0]
# ['5', '500', 'sqrt', '12', 'apriori', 'SC', 3.167346031665802, 7.07, 120.09, 0.78]
# ['5', '500', 'sqrt', '12', 'fpgrowth', 'kmedoids', 2.995513768196106, 4.1, 120.21, 0.06]
# ['5', '500', 'sqrt', '12', 'fpgrowth', 'OPTICS', 3.07049991607666, 0.0, 0.0, 0.0]
# ['5', '500', 'sqrt', '12', 'fpgrowth', 'SC', 3.0840782642364504, 7.07, 120.09, 0.78]
# ['5', '500', 'sqrt', '13', 'apriori', '_', 0.36725125074386594, 3.33, 124.54, 0.02]
# ['5', '500', 'sqrt', '13', 'fpgrowth', '_', 0.8312984466552734, 3.54, 124.54, 0.01]
# ['5', '500', 'sqrt', '23', '_', 'kmedoids', 2.9721172213554383, 4.39, 125.2, 0.06]
# ['5', '500', 'sqrt', '23', '_', 'OPTICS', 3.064763104915619, 3.89, 124.54, 0.04]
# ['5', '500', 'sqrt', '23', '_', 'SC', 3.0689446401596068, 7.3, 125.29, 0.8]
# ['5', '500', 'sqrt', '123', 'apriori', 'kmedoids', 2.9991786527633666, 4.25, 125.2, 0.06]
# ['5', '500', 'sqrt', '123', 'apriori', 'OPTICS', 3.0977215552330017, 4.29, 124.54, 0.02]
# ['5', '500', 'sqrt', '123', 'apriori', 'SC', 3.2718666315078737, 7.27, 125.29, 0.78]
# ['5', '500', 'sqrt', '123', 'fpgrowth', 'kmedoids', 2.9827694487571716, 4.39, 125.2, 0.06]
# ['5', '500', 'sqrt', '123', 'fpgrowth', 'OPTICS', 3.094775619506836, 3.89, 124.54, 0.04]
# ['5', '500', 'sqrt', '123', 'fpgrowth', 'SC', 3.1525358247756956, 7.3, 125.29, 0.8]
# ['5', '500', 'log2', 'NoRed', '_', '_', 0.3538316082954407, 0.0, 0.0, 0.0]
# ['5', '500', 'log2', '1', 'apriori', '_', 0.36115269422531127, 0.0, 0.0, 0.0]
# ['5', '500', 'log2', '1', 'fpgrowth', '_', 0.3623188424110413, 0.0, 0.0, 0.0]
# ['5', '500', 'log2', '2', '_', 'kmedoids', 3.1726860356330873, 3.12, 121.91, 0.0]
# ['5', '500', 'log2', '2', '_', 'OPTICS', 3.247860732078552, 0.0, 0.0, 0.0]
# ['5', '500', 'log2', '2', '_', 'SC', 3.5506289935112, 3.29, 120.73, 0.16]
# ['5', '500', 'log2', '3', '_', '_', 0.35754578351974486, 3.34, 125.67, 0.02]
# ['5', '500', 'log2', '12', 'apriori', 'kmedoids', 3.211308879852295, 3.12, 121.91, 0.0]
# ['5', '500', 'log2', '12', 'apriori', 'OPTICS', 3.2840498185157774, 0.0, 0.0, 0.0]
# ['5', '500', 'log2', '12', 'apriori', 'SC', 3.4256809878349306, 3.29, 120.73, 0.16]
# ['5', '500', 'log2', '12', 'fpgrowth', 'kmedoids', 3.20244321346283, 3.12, 121.91, 0.0]
# ['5', '500', 'log2', '12', 'fpgrowth', 'OPTICS', 3.2876862716674804, 0.0, 0.0, 0.0]
# ['5', '500', 'log2', '12', 'fpgrowth', 'SC', 3.331150002479553, 3.29, 120.73, 0.16]
# ['5', '500', 'log2', '13', 'apriori', '_', 0.36301408529281615, 3.34, 125.67, 0.02]
# ['5', '500', 'log2', '13', 'fpgrowth', '_', 0.366273078918457, 3.34, 125.67, 0.02]
# ['5', '500', 'log2', '23', '_', 'kmedoids', 3.321134874820709, 3.23, 126.71, 0.0]
# ['5', '500', 'log2', '23', '_', 'OPTICS', 3.266067841053009, 2.98, 125.67, 0.03]
# ['5', '500', 'log2', '23', '_', 'SC', 3.2989905762672422, 3.48, 126.19, 0.16]
# ['5', '500', 'log2', '123', 'apriori', 'kmedoids', 3.191015839576721, 3.23, 126.71, 0.0]
# ['5', '500', 'log2', '123', 'apriori', 'OPTICS', 3.28076459646225, 2.75, 125.67, 0.01]
# ['5', '500', 'log2', '123', 'apriori', 'SC', 3.245407123565674, 3.46, 126.19, 0.16]
# ['5', '500', 'log2', '123', 'fpgrowth', 'kmedoids', 2.8566770362854004, 3.23, 126.71, 0.0]
# ['5', '500', 'log2', '123', 'fpgrowth', 'OPTICS', 3.0431419587135315, 2.98, 125.67, 0.03]
# ['5', '500', 'log2', '123', 'fpgrowth', 'SC', 3.304714677333832, 3.48, 126.19, 0.16]
# ['5', '500', '0.75', 'NoRed', '_', '_', 0.35110294103622436, 0.0, 0.0, 0.0]
# ['5', '500', '0.75', '1', 'apriori', '_', 0.36508248329162596, 6.5, 118.48, 1.41]
# ['5', '500', '0.75', '1', 'fpgrowth', '_', 0.36428906202316286, 6.5, 118.48, 1.41]
# ['5', '500', '0.75', '2', '_', 'kmedoids', 2.432655997276306, 2.88, 144.14, 0.72]
# ['5', '500', '0.75', '2', '_', 'OPTICS', 2.571512634754181, 0.49, 67.2, 0.07]
# ['5', '500', '0.75', '2', '_', 'SC', 4.460245800018311, 4.87, 144.2, 1.14]
# ['5', '500', '0.75', '3', '_', '_', 0.35757960319519044, 1.28, 150.17, 0.46]
# ['5', '500', '0.75', '12', 'apriori', 'kmedoids', 1.24085839509964, 6.84, 150.16, 1.51]
# ['5', '500', '0.75', '12', 'apriori', 'OPTICS', 1.279428551197052, 6.53, 121.39, 1.42]
# ['5', '500', '0.75', '12', 'apriori', 'SC', 2.931679141521454, 7.14, 148.21, 1.51]
# ['5', '500', '0.75', '12', 'fpgrowth', 'kmedoids', 1.244339406490326, 6.84, 150.16, 1.51]
# ['5', '500', '0.75', '12', 'fpgrowth', 'OPTICS', 1.2823051166534425, 6.53, 121.39, 1.42]
# ['5', '500', '0.75', '12', 'fpgrowth', 'SC', 3.0434791350364687, 7.14, 148.14, 1.51]
# ['5', '500', '0.75', '13', 'apriori', '_', 0.3640166687965393, 6.63, 151.77, 1.45]
# ['5', '500', '0.75', '13', 'fpgrowth', '_', 0.3657412123680115, 6.7, 151.77, 1.44]
# ['5', '500', '0.75', '23', '_', 'kmedoids', 2.4319478940963744, 2.91, 151.48, 0.73]
# ['5', '500', '0.75', '23', '_', 'OPTICS', 2.8559095072746277, 0.92, 150.69, 0.18]
# ['5', '500', '0.75', '23', '_', 'SC', 3.933552854061127, 4.89, 150.42, 1.15]
# ['5', '500', '0.75', '123', 'apriori', 'kmedoids', 1.2380230259895324, 6.85, 151.57, 1.51]
# ['5', '500', '0.75', '123', 'apriori', 'OPTICS', 1.2805060744285583, 6.62, 151.88, 1.43]
# ['5', '500', '0.75', '123', 'apriori', 'SC', 3.031441078186035, 7.14, 151.6, 1.51]
# ['5', '500', '0.75', '123', 'fpgrowth', 'kmedoids', 1.2423213958740233, 6.84, 151.57, 1.51]
# ['5', '500', '0.75', '123', 'fpgrowth', 'OPTICS', 1.281856324672699, 6.61, 151.88, 1.44]
# ['5', '500', '0.75', '123', 'fpgrowth', 'SC', 3.003507797718048, 7.14, 151.6, 1.51]
# ['5', '500', 'None', 'NoRed', '_', '_', 0.35788491010665896, 0.0, 0.0, 0.0]
# ['5', '500', 'None', '1', 'apriori', '_', 0.37219150304794313, 1.81, 86.31, 0.51]
# ['5', '500', 'None', '1', 'fpgrowth', '_', 0.372652268409729, 1.81, 78.15, 0.32]
# ['5', '500', 'None', '2', '_', 'kmedoids', 2.748422918319702, 1.67, 130.93, 0.32]
# ['5', '500', 'None', '2', '_', 'OPTICS', 2.8185951709747314, 0.03, 38.35, 0.0]
# ['5', '500', 'None', '2', '_', 'SC', 9.033667597770691, 2.02, 138.43, 0.47]
# ['5', '500', 'None', '3', '_', '_', 0.36111621141433714, 0.31, 154.8, 0.05]
# ['5', '500', 'None', '12', 'apriori', 'kmedoids', 2.103959081172943, 2.41, 140.76, 0.76]
# ['5', '500', 'None', '12', 'apriori', 'OPTICS', 2.041788160800934, 1.81, 89.3, 0.51]
# ['5', '500', 'None', '12', 'apriori', 'SC', 8.854348418712616, 2.57, 147.63, 0.81]
# ['5', '500', 'None', '12', 'fpgrowth', 'kmedoids', 2.0545875954627992, 2.41, 144.17, 0.57]
# ['5', '500', 'None', '12', 'fpgrowth', 'OPTICS', 2.146371850967407, 1.81, 81.14, 0.32]
# ['5', '500', 'None', '12', 'fpgrowth', 'SC', 8.474990332126618, 2.57, 146.31, 0.62]
# ['5', '500', 'None', '13', 'apriori', '_', 0.37401371479034423, 1.85, 155.57, 0.52]
# ['5', '500', 'None', '13', 'fpgrowth', '_', 0.37538387537002565, 1.91, 155.99, 0.34]
# ['5', '500', 'None', '23', '_', 'kmedoids', 2.7367934727668763, 1.79, 155.02, 0.35]
# ['5', '500', 'None', '23', '_', 'OPTICS', 2.8110781621932985, 0.32, 155.31, 0.07]
# ['5', '500', 'None', '23', '_', 'SC', 8.679250333309174, 2.02, 154.53, 0.47]
# ['5', '500', 'None', '123', 'apriori', 'kmedoids', 1.8791845488548278, 2.41, 155.71, 0.76]
# ['5', '500', 'None', '123', 'apriori', 'OPTICS', 2.0534200406074525, 1.96, 155.56, 0.56]
# ['5', '500', 'None', '123', 'apriori', 'SC', 8.94134438753128, 2.57, 155.66, 0.81]
# ['5', '500', 'None', '123', 'fpgrowth', 'kmedoids', 2.0382553434371946, 2.41, 156.15, 0.57]
# ['5', '500', 'None', '123', 'fpgrowth', 'OPTICS', 2.210695495605469, 1.88, 156.17, 0.35]
# ['5', '500', 'None', '123', 'fpgrowth', 'SC', 8.349571118354797, 2.57, 155.89, 0.62]
# ['7', '10', 'sqrt', 'NoRed', '_', '_', 0.21936976194381713, 0.0, 0.0, 0.0]
# ['7', '10', 'sqrt', '1', 'apriori', '_', 0.30478748083114626, 4.16, 2.25, 1.0]
# ['7', '10', 'sqrt', '1', 'fpgrowth', '_', 0.2948049306869507, 4.42, 2.29, 0.94]
# ['7', '10', 'sqrt', '2', '_', 'kmedoids', 0.21916549921035766, 4.06, 2.11, 1.27]
# ['7', '10', 'sqrt', '2', '_', 'OPTICS', 0.22350265741348266, 0.0, 0.0, 0.0]
# ['7', '10', 'sqrt', '2', '_', 'SC', 0.24093483209609987, 3.19, 1.88, 0.68]
# ['7', '10', 'sqrt', '3', '_', '_', 0.2194819712638855, 3.35, 2.17, 0.96]
# ...
# ['10', '100', 'sqrt', '1', 'fpgrowth', '_', 0.26150089740753174, 0.0, 0.0, 0.0]
# ['10', '100', 'sqrt', '2', '_', 'kmedoids', 0.3717271685600281, 3.01, 22.68, 0.04]
# ['10', '100', 'sqrt', '2', '_', 'OPTICS', 0.3829106068611145, 0.0, 0.0, 0.0]
# ['10', '100', 'sqrt', '2', '_', 'SC', 0.40025909900665285, 2.99, 23.61, 0.04]
# ['10', '100', 'sqrt', '3', '_', '_', 0.24601000308990478, 4.14, 27.9, 0.04]
# ['10', '100', 'sqrt', '12', 'apriori', 'kmedoids', 0.3892224812507629, 3.01, 22.68, 0.04]
# ['10', '100', 'sqrt', '12', 'apriori', 'OPTICS', 0.40068587064743044, 0.0, 0.0, 0.0]
# ['10', '100', 'sqrt', '12', 'apriori', 'SC', 0.41578266143798825, 2.99, 23.61, 0.04]
# ['10', '100', 'sqrt', '12', 'fpgrowth', 'kmedoids', 0.39070486783981323, 3.01, 22.68, 0.04]
# ['10', '100', 'sqrt', '12', 'fpgrowth', 'OPTICS', 0.4030331683158874, 0.0, 0.0, 0.0]
# ['10', '100', 'sqrt', '12', 'fpgrowth', 'SC', 0.4193691039085388, 2.99, 23.61, 0.04]
# ['10', '100', 'sqrt', '13', 'apriori', '_', 0.26052859544754026, 3.1, 27.9, 0.02]
# ['10', '100', 'sqrt', '13', 'fpgrowth', '_', 0.26118084192276003, 4.14, 27.9, 0.04]
# ['10', '100', 'sqrt', '23', '_', 'kmedoids', 0.37269131422042845, 3.87, 27.95, 0.04]
# ['10', '100', 'sqrt', '23', '_', 'OPTICS', 0.38406983613967893, 3.71, 27.9, 0.01]
# ['10', '100', 'sqrt', '23', '_', 'SC', 0.3998415017127991, 3.66, 27.99, 0.04]
# ['10', '100', 'sqrt', '123', 'apriori', 'kmedoids', 0.3894974803924561, 3.85, 27.95, 0.04]
# ['10', '100', 'sqrt', '123', 'apriori', 'OPTICS', 0.40046671867370603, 3.3, 27.9, 0.0]
# ['10', '100', 'sqrt', '123', 'apriori', 'SC', 0.4153701066970825, 3.62, 27.99, 0.04]
# ['10', '100', 'sqrt', '123', 'fpgrowth', 'kmedoids', 0.38946133375167846, 3.87, 27.95, 0.04]
# ['10', '100', 'sqrt', '123', 'fpgrowth', 'OPTICS', 0.40397908687591555, 3.71, 27.9, 0.01]
# ['10', '100', 'sqrt', '123', 'fpgrowth', 'SC', 0.41847620487213133, 3.66, 27.99, 0.04]
# ['10', '100', 'log2', 'NoRed', '_', '_', 0.2463993501663208, 0.0, 0.0, 0.0]
# ['10', '100', 'log2', '1', 'apriori', '_', 0.2580696702003479, 0.0, 0.0, 0.0]
# ['10', '100', 'log2', '1', 'fpgrowth', '_', 0.2589891457557678, 0.0, 0.0, 0.0]
# ['10', '100', 'log2', '2', '_', 'kmedoids', 0.36746296644210813, 2.75, 20.66, 0.0]
# ['10', '100', 'log2', '2', '_', 'OPTICS', 0.37926836490631105, 0.0, 0.0, 0.0]
# ['10', '100', 'log2', '2', '_', 'SC', 0.395611834526062, 2.85, 20.92, 0.0]
# ['10', '100', 'log2', '3', '_', '_', 0.24632350206375123, 3.56, 25.42, 0.03]
# ['10', '100', 'log2', '12', 'apriori', 'kmedoids', 0.3811129355430603, 2.75, 20.66, 0.0]
# ['10', '100', 'log2', '12', 'apriori', 'OPTICS', 0.3920071458816528, 0.0, 0.0, 0.0]
# ['10', '100', 'log2', '12', 'apriori', 'SC', 0.40708216428756716, 2.85, 20.92, 0.0]
# ['10', '100', 'log2', '12', 'fpgrowth', 'kmedoids', 0.662572271823883, 2.75, 20.66, 0.0]
# ['10', '100', 'log2', '12', 'fpgrowth', 'OPTICS', 0.38872178316116335, 0.0, 0.0, 0.0]
# ['10', '100', 'log2', '12', 'fpgrowth', 'SC', 0.4056356930732727, 2.85, 20.92, 0.0]
# ['10', '100', 'log2', '13', 'apriori', '_', 0.2577929162979126, 3.7, 25.42, 0.0]
# ['10', '100', 'log2', '13', 'fpgrowth', '_', 0.2589039707183838, 3.56, 25.42, 0.03]
# ['10', '100', 'log2', '23', '_', 'kmedoids', 0.36775286197662355, 3.68, 25.6, 0.0]
# ['10', '100', 'log2', '23', '_', 'OPTICS', 0.3789809632301331, 3.47, 25.42, 0.0]
# ['10', '100', 'log2', '23', '_', 'SC', 0.3955261826515198, 3.67, 25.48, 0.0]
# ['10', '100', 'log2', '123', 'apriori', 'kmedoids', 0.38152681827545165, 3.77, 25.6, 0.0]
# ['10', '100', 'log2', '123', 'apriori', 'OPTICS', 0.3931465244293213, 3.76, 25.42, 0.0]
# ['10', '100', 'log2', '123', 'apriori', 'SC', 0.40822356700897217, 3.65, 25.48, 0.0]
# ['10', '100', 'log2', '123', 'fpgrowth', 'kmedoids', 0.38354624032974244, 3.68, 25.6, 0.0]
# ['10', '100', 'log2', '123', 'fpgrowth', 'OPTICS', 0.39506290197372435, 3.47, 25.42, 0.0]
# ['10', '100', 'log2', '123', 'fpgrowth', 'SC', 0.410553936958313, 3.67, 25.48, 0.0]
# ['10', '100', '0.75', 'NoRed', '_', '_', 0.24827725410461426, 0.0, 0.0, 0.0]
# ['10', '100', '0.75', '1', 'apriori', '_', 0.4469488191604614, 5.29, 14.2, 1.0]
# ['10', '100', '0.75', '1', 'fpgrowth', '_', 0.4386135721206665, 5.29, 14.24, 1.0]
# ['10', '100', '0.75', '2', '_', 'kmedoids', 0.3802164578437805, 3.28, 27.42, 0.49]
# ['10', '100', '0.75', '2', '_', 'OPTICS', 0.39266583442687986, 0.03, 0.26, 0.0]
# ['10', '100', '0.75', '2', '_', 'SC', 0.40650625467300416, 4.55, 28.36, 0.86]
# ['10', '100', '0.75', '3', '_', '_', 0.2482949376106262, 2.34, 33.15, 0.36]
# ['10', '100', '0.75', '12', 'apriori', 'kmedoids', 0.5416474962234497, 7.2, 29.52, 1.31]
# ['10', '100', '0.75', '12', 'apriori', 'OPTICS', 0.5520306348800659, 5.3, 14.47, 1.0]
# ['10', '100', '0.75', '12', 'apriori', 'SC', 0.5654415822029114, 7.89, 30.12, 1.45]
# ['10', '100', '0.75', '12', 'fpgrowth', 'kmedoids', 0.5349066781997681, 7.2, 29.52, 1.31]
# ['10', '100', '0.75', '12', 'fpgrowth', 'OPTICS', 0.5463207983970642, 5.3, 14.51, 1.0]
# ['10', '100', '0.75', '12', 'fpgrowth', 'SC', 0.5597501397132874, 7.89, 30.11, 1.45]
# ['10', '100', '0.75', '13', 'apriori', '_', 0.44711732149124145, 6.56, 33.16, 1.2]
# ['10', '100', '0.75', '13', 'fpgrowth', '_', 0.4413008689880371, 6.51, 33.16, 1.19]
# ['10', '100', '0.75', '23', '_', 'kmedoids', 0.38120786666870116, 3.96, 33.17, 0.6]
# ['10', '100', '0.75', '23', '_', 'OPTICS', 0.39453644037246705, 2.57, 33.17, 0.38]
# ['10', '100', '0.75', '23', '_', 'SC', 0.4072662711143494, 4.98, 33.01, 0.95]
# ['10', '100', '0.75', '123', 'apriori', 'kmedoids', 0.5411648178100585, 7.37, 33.13, 1.36]
# ['10', '100', '0.75', '123', 'apriori', 'OPTICS', 0.5526616525650024, 6.86, 33.17, 1.21]
# ['10', '100', '0.75', '123', 'apriori', 'SC', 0.564782304763794, 8.05, 33.01, 1.49]
# ['10', '100', '0.75', '123', 'fpgrowth', 'kmedoids', 0.5372209668159484, 7.54, 33.13, 1.35]
# ['10', '100', '0.75', '123', 'fpgrowth', 'OPTICS', 0.5476845026016235, 6.66, 33.17, 1.21]
# ['10', '100', '0.75', '123', 'fpgrowth', 'SC', 0.5592195200920105, 8.07, 33.01, 1.52]
# ['10', '100', 'None', 'NoRed', '_', '_', 0.24808467864990236, 0.0, 0.0, 0.0]
# ['10', '100', 'None', '1', 'apriori', '_', 0.6727791905403138, 4.7, 16.82, 0.75]
# ['10', '100', 'None', '1', 'fpgrowth', '_', 0.4707950091361999, 4.7, 16.78, 0.75]
# ['10', '100', 'None', '2', '_', 'kmedoids', 0.38051920652389526, 2.16, 27.85, 0.4]
# ['10', '100', 'None', '2', '_', 'OPTICS', 0.3877681112289429, 0.03, 1.43, 0.0]
# ['10', '100', 'None', '2', '_', 'SC', 0.4026493763923645, 2.68, 29.45, 0.55]
# ['10', '100', 'None', '3', '_', '_', 0.24849834203720092, 2.11, 33.26, 0.32]
# ['10', '100', 'None', '12', 'apriori', 'kmedoids', 0.5735904288291931, 5.75, 29.75, 0.93]
# ['10', '100', 'None', '12', 'apriori', 'OPTICS', 0.5794668269157409, 4.7, 18.13, 0.75]
# ['10', '100', 'None', '12', 'apriori', 'SC', 0.5949956464767456, 6.05, 30.54, 1.0]
# ['10', '100', 'None', '12', 'fpgrowth', 'kmedoids', 0.5652301931381225, 5.75, 29.75, 0.93]
# ['10', '100', 'None', '12', 'fpgrowth', 'OPTICS', 0.5734060192108155, 4.7, 18.09, 0.75]
# ['10', '100', 'None', '12', 'fpgrowth', 'SC', 0.5882628798484802, 6.05, 30.51, 1.0]
# ['10', '100', 'None', '13', 'apriori', '_', 0.4828329014778137, 5.22, 33.24, 0.85]
# ['10', '100', 'None', '13', 'fpgrowth', '_', 0.4750480985641479, 5.43, 33.24, 0.85]
# ['10', '100', 'None', '23', '_', 'kmedoids', 0.3751766300201416, 2.44, 33.32, 0.48]
# ['10', '100', 'None', '23', '_', 'OPTICS', 0.3885224390029907, 1.84, 33.29, 0.32]
# ['10', '100', 'None', '23', '_', 'SC', 0.40261056900024417, 2.92, 33.23, 0.6]
# ['10', '100', 'None', '123', 'apriori', 'kmedoids', 0.5705652546882629, 5.91, 33.31, 0.96]
# ['10', '100', 'None', '123', 'apriori', 'OPTICS', 0.5801111030578613, 5.26, 33.27, 0.89]
# ['10', '100', 'None', '123', 'apriori', 'SC', 0.5948735761642456, 6.1, 33.28, 1.02]
# ['10', '100', 'None', '123', 'fpgrowth', 'kmedoids', 0.5636897826194763, 5.88, 33.31, 0.97]
# ['10', '100', 'None', '123', 'fpgrowth', 'OPTICS', 0.5748732757568359, 5.45, 33.27, 0.87]
# ['10', '100', 'None', '123', 'fpgrowth', 'SC', 0.5913895726203918, 6.13, 33.28, 1.02]
# ['10', '500', 'sqrt', 'NoRed', '_', '_', 0.3427799654006958, 0.0, 0.0, 0.0]
# ['10', '500', 'sqrt', '1', 'apriori', '_', 0.37473321199417114, 0.0, 0.0, 0.0]
# ['10', '500', 'sqrt', '1', 'fpgrowth', '_', 0.38772358894348147, 0.0, 0.0, 0.0]
# ['10', '500', 'sqrt', '2', '_', 'kmedoids', 4.175958645343781, 2.32, 133.48, 0.0]
# ['10', '500', 'sqrt', '2', '_', 'OPTICS', 4.459776175022125, 0.0, 0.0, 0.0]
# ['10', '500', 'sqrt', '2', '_', 'SC', 4.271933796405793, 2.28, 134.04, 0.0]
# ['10', '500', 'sqrt', '3', '_', '_', 0.3465842127799988, 2.27, 138.41, 0.0]
# ['10', '500', 'sqrt', '12', 'apriori', 'kmedoids', 4.235922570228577, 2.32, 133.48, 0.0]
# ['10', '500', 'sqrt', '12', 'apriori', 'OPTICS', 4.300058550834656, 0.0, 0.0, 0.0]
# ['10', '500', 'sqrt', '12', 'apriori', 'SC', 4.567768449783325, 2.28, 134.04, 0.0]
# ['10', '500', 'sqrt', '12', 'fpgrowth', 'kmedoids', 4.257866306304932, 2.32, 133.48, 0.0]
# ['10', '500', 'sqrt', '12', 'fpgrowth', 'OPTICS', 4.339377119541168, 0.0, 0.0, 0.0]
# ['10', '500', 'sqrt', '12', 'fpgrowth', 'SC', 4.374734907150269, 2.28, 134.04, 0.0]
# ['10', '500', 'sqrt', '13', 'apriori', '_', 0.37865252494812013, 2.76, 138.41, 0.0]
# ['10', '500', 'sqrt', '13', 'fpgrowth', '_', 0.39177814245223996, 2.27, 138.41, 0.0]
# ['10', '500', 'sqrt', '23', '_', 'kmedoids', 4.230717403888702, 2.42, 138.69, 0.0]
# ['10', '500', 'sqrt', '23', '_', 'OPTICS', 4.232395734786987, 1.93, 138.41, 0.0]
# ['10', '500', 'sqrt', '23', '_', 'SC', 4.278681671619415, 2.35, 138.86, 0.0]
# ['10', '500', 'sqrt', '123', 'apriori', 'kmedoids', 4.237106173038483, 2.43, 138.69, 0.0]
# ['10', '500', 'sqrt', '123', 'apriori', 'OPTICS', 4.535588886737823, 2.63, 138.41, 0.0]
# ['10', '500', 'sqrt', '123', 'apriori', 'SC', 4.333850839138031, 2.41, 138.86, 0.0]
# ['10', '500', 'sqrt', '123', 'fpgrowth', 'kmedoids', 4.26571236371994, 2.42, 138.69, 0.0]
# ['10', '500', 'sqrt', '123', 'fpgrowth', 'OPTICS', 4.92878901720047, 1.93, 138.41, 0.0]
# ['10', '500', 'sqrt', '123', 'fpgrowth', 'SC', 4.352699415683746, 2.35, 138.86, 0.0]
# ['10', '500', 'log2', 'NoRed', '_', '_', 0.33858509063720704, 0.0, 0.0, 0.0]
# ['10', '500', 'log2', '1', 'apriori', '_', 0.35979050159454345, 0.0, 0.0, 0.0]
# ['10', '500', 'log2', '1', 'fpgrowth', '_', 0.3748558497428894, 0.0, 0.0, 0.0]
# ['10', '500', 'log2', '2', '_', 'kmedoids', 3.9877489686012266, 1.31, 125.63, 0.0]
# ['10', '500', 'log2', '2', '_', 'OPTICS', 4.053005290031433, 0.0, 0.0, 0.0]
# ['10', '500', 'log2', '2', '_', 'SC', 4.101540508270264, 1.25, 125.48, 0.0]
# ['10', '500', 'log2', '3', '_', '_', 0.3449037384986877, 1.52, 129.65, 0.0]
# ['10', '500', 'log2', '12', 'apriori', 'kmedoids', 4.064937827587127, 1.31, 125.63, 0.0]
# ['10', '500', 'log2', '12', 'apriori', 'OPTICS', 4.241650903224945, 0.0, 0.0, 0.0]
# ['10', '500', 'log2', '12', 'apriori', 'SC', 4.170897417068481, 1.25, 125.48, 0.0]
# ['10', '500', 'log2', '12', 'fpgrowth', 'kmedoids', 4.061565651893615, 1.31, 125.63, 0.0]
# ['10', '500', 'log2', '12', 'fpgrowth', 'OPTICS', 4.120694329738617, 0.0, 0.0, 0.0]
# ['10', '500', 'log2', '12', 'fpgrowth', 'SC', 4.472054626941681, 1.25, 125.48, 0.0]
# ['10', '500', 'log2', '13', 'apriori', '_', 0.36895808935165403, 1.46, 129.65, 0.0]
# ['10', '500', 'log2', '13', 'fpgrowth', '_', 0.38179606676101685, 1.52, 129.65, 0.0]
# ['10', '500', 'log2', '23', '_', 'kmedoids', 3.9896134543418884, 1.39, 130.82, 0.0]
# ['10', '500', 'log2', '23', '_', 'OPTICS', 4.057824449539185, 1.46, 129.65, 0.0]
# ['10', '500', 'log2', '23', '_', 'SC', 4.103429758548737, 1.32, 130.62, 0.0]
# ['10', '500', 'log2', '123', 'apriori', 'kmedoids', 4.130826213359833, 1.42, 130.82, 0.0]
# ['10', '500', 'log2', '123', 'apriori', 'OPTICS', 4.124643094539643, 1.11, 129.65, 0.0]
# ['10', '500', 'log2', '123', 'apriori', 'SC', 4.161211276054383, 1.37, 130.62, 0.0]
# ['10', '500', 'log2', '123', 'fpgrowth', 'kmedoids', 4.06044861793518, 1.39, 130.82, 0.0]
# ['10', '500', 'log2', '123', 'fpgrowth', 'OPTICS', 4.1292357563972475, 1.46, 129.65, 0.0]
# ['10', '500', 'log2', '123', 'fpgrowth', 'SC', 4.470936093330383, 1.32, 130.62, 0.0]
# ['10', '500', '0.75', 'NoRed', '_', '_', 0.3466248393058777, 0.0, 0.0, 0.0]
# ['10', '500', '0.75', '1', 'apriori', '_', 0.5383620142936707, 8.94, 79.55, 1.52]
# ['10', '500', '0.75', '1', 'fpgrowth', '_', 0.5320542192459107, 8.94, 79.55, 1.52]
# ['10', '500', '0.75', '2', '_', 'kmedoids', 4.251832120418548, 3.66, 159.88, 0.56]
# ['10', '500', '0.75', '2', '_', 'OPTICS', 4.341728546619415, 0.0, 0.0, 0.0]
# ['10', '500', '0.75', '2', '_', 'SC', 4.562685649394989, 11.64, 160.07, 1.82]
# ['10', '500', '0.75', '3', '_', '_', 0.3514961004257202, 2.4, 167.06, 0.33]
# ['10', '500', '0.75', '12', 'apriori', 'kmedoids', 3.2320672988891603, 10.9, 162.58, 1.81]
# ['10', '500', '0.75', '12', 'apriori', 'OPTICS', 3.2946473932266236, 8.94, 79.55, 1.52]
# ['10', '500', '0.75', '12', 'apriori', 'SC', 3.3817071151733398, 14.77, 162.81, 2.42]
# ['10', '500', '0.75', '12', 'fpgrowth', 'kmedoids', 3.209252691268921, 10.9, 162.58, 1.81]
# ['10', '500', '0.75', '12', 'fpgrowth', 'OPTICS', 3.272241761684418, 8.94, 79.55, 1.52]
# ['10', '500', '0.75', '12', 'fpgrowth', 'SC', 3.4182941055297853, 14.77, 162.81, 2.42]
# ['10', '500', '0.75', '13', 'apriori', '_', 0.5402687764167786, 9.88, 167.15, 1.66]
# ['10', '500', '0.75', '13', 'fpgrowth', '_', 0.534653034210205, 9.88, 167.15, 1.65]
# ['10', '500', '0.75', '23', '_', 'kmedoids', 4.266919484138489, 3.73, 166.81, 0.56]
# ['10', '500', '0.75', '23', '_', 'OPTICS', 4.34339302778244, 2.47, 167.06, 0.47]
# ['10', '500', '0.75', '23', '_', 'SC', 4.3771518087387085, 11.76, 166.57, 1.83]
# ['10', '500', '0.75', '123', 'apriori', 'kmedoids', 3.5885614728927613, 10.95, 166.81, 1.81]
# ['10', '500', '0.75', '123', 'apriori', 'OPTICS', 3.2996585512161256, 10.11, 167.15, 1.66]
# ['10', '500', '0.75', '123', 'apriori', 'SC', 3.3823292446136475, 14.85, 166.62, 2.42]
# ['10', '500', '0.75', '123', 'fpgrowth', 'kmedoids', 3.2077783846855166, 10.94, 166.81, 1.81]
# ['10', '500', '0.75', '123', 'fpgrowth', 'OPTICS', 3.2768084955215455, 10.04, 167.15, 1.7]
# ['10', '500', '0.75', '123', 'fpgrowth', 'SC', 3.358960225582123, 14.83, 166.62, 2.42]
# ['10', '500', 'None', 'NoRed', '_', '_', 0.3483320736885071, 0.0, 0.0, 0.0]
# ['10', '500', 'None', '1', 'apriori', '_', 0.549003803730011, 7.3, 90.25, 1.31]
# ['10', '500', 'None', '1', 'fpgrowth', '_', 0.5414578032493591, 7.3, 90.06, 1.3]
# ['10', '500', 'None', '2', '_', 'kmedoids', 3.9357034182548523, 2.39, 159.86, 0.6]
# ['10', '500', 'None', '2', '_', 'OPTICS', 4.022540125846863, 0.09, 7.18, 0.02]
# ['10', '500', 'None', '2', '_', 'SC', 4.529665977954864, 9.36, 159.87, 1.56]
# ['10', '500', 'None', '3', '_', '_', 0.3544676113128662, 2.1, 168.0, 0.57]
# ['10', '500', 'None', '12', 'apriori', 'kmedoids', 2.9150445365905764, 8.45, 163.8, 1.55]
# ['10', '500', 'None', '12', 'apriori', 'OPTICS', 2.8846298623085023, 7.33, 92.47, 1.32]
# ['10', '500', 'None', '12', 'apriori', 'SC', 3.4860077786445616, 11.64, 164.14, 2.12]
# ['10', '500', 'None', '12', 'fpgrowth', 'kmedoids', 2.842405457496643, 8.45, 163.76, 1.54]
# ['10', '500', 'None', '12', 'fpgrowth', 'OPTICS', 2.8951921343803404, 7.33, 92.28, 1.31]
# ['10', '500', 'None', '12', 'fpgrowth', 'SC', 3.4991972398757936, 11.64, 164.13, 2.11]
# ['10', '500', 'None', '13', 'apriori', '_', 0.5505280900001526, 8.03, 167.92, 1.41]
# ['10', '500', 'None', '13', 'fpgrowth', '_', 0.8607665777206421, 8.15, 167.93, 1.45]
# ['10', '500', 'None', '23', '_', 'kmedoids', 3.9251934838294984, 2.54, 167.67, 0.63]
# ['10', '500', 'None', '23', '_', 'OPTICS', 4.029490141868592, 2.15, 168.07, 0.33]
# ['10', '500', 'None', '23', '_', 'SC', 8.75481437921524, 9.49, 167.85, 1.59]
# ['10', '500', 'None', '123', 'apriori', 'kmedoids', 2.9466344213485716, 8.46, 167.73, 1.55]
# ['10', '500', 'None', '123', 'apriori', 'OPTICS', 2.8881879329681395, 7.81, 167.95, 1.38]
# ['10', '500', 'None', '123', 'apriori', 'SC', 3.4883571648597718, 11.68, 167.69, 2.12]
# ['10', '500', 'None', '123', 'fpgrowth', 'kmedoids', 2.8424273204803465, 8.53, 167.74, 1.54]
# ['10', '500', 'None', '123', 'fpgrowth', 'OPTICS', 2.9128536581993103, 8.04, 167.96, 1.4]
# ['10', '500', 'None', '123', 'fpgrowth', 'SC', 3.8715443658828734, 11.72, 167.7, 2.12]

# %%
from tqdm import tqdm
import time  #10 trees

results = []
iterr = 100
with tqdm(total=2*3*4*2) as pbar:
    for i in [7,10]:
        for j in [100]: #leipei to 10
            for o in ['sqrt','log2', 0.75, None]:#0.75,None
                parameters = [{
                    'max_depth': [i],
                    'max_features': [o],
                    'bootstrap': [True],
                    'min_samples_leaf' : [2],
                    'n_estimators': [j]
                }]
                lf = LionForests(None, False, None, feature_names, class_names, categorical_features)
                lf.train(X, y, params=parameters)
                tlf = 0
                fr = 0
                frr = 0
                pr = 0
                for inde in range(iterr):
                    t_a = time.time()
                    a, b, c, d, e, g, h, _, _ = lf.following_breadcrumbs(X[inde], False, None, None, True)
                    fr = fr + c - e
                    frr = frr + g - h 
                    pr = pr + b - d
                    tlf = tlf + time.time() - t_a
                results.append([str(i),str(j),str(o),'NoRed_Old','_','_', tlf/iterr, fr/iterr, pr/iterr, frr/iterr])
                print([str(i),str(j),str(o),'NoRed_Old','_','_', tlf/iterr, fr/iterr, pr/iterr, frr/iterr])
                pbar.update(1)
                tlf = 0
                fr = 0
                frr = 0
                pr = 0                
                for inde in range(iterr):
                    t_a = time.time()
                    a, b, c, d, e, g, h, _, _ = lf.following_breadcrumbs(X[inde], True, 'apriori', 'kmedoids', True)
                    fr = fr + c - e
                    frr = frr + g - h 
                    pr = pr + b - d
                    tlf = tlf + time.time() - t_a
                results.append([str(i),str(j),str(o),'123_Old','_','_', tlf/iterr, fr/iterr, pr/iterr, frr/iterr])
                print([str(i),str(j),str(o),'123_Old','_','_', tlf/iterr, fr/iterr, pr/iterr, frr/iterr])
                pbar.update(1)
                
    #print(results)
# Out:
#   2%|█▋                                                                            | 1/48 [26:26<20:42:37, 1586.32s/it]
# ['10', '100', 'None', 'NoRed_Old', '_', '_', 14.149667129516601, 0.0, 0.0, 0.0]
#   2%|█▍                                                                     | 1/48 [90:40:51<4262:00:31, 326451.74s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-31a886d1bc40> in <module>
#      37                 for inde in range(iterr):
#      38                     t_a = time.time()
# ---> 39                     a, b, c, d, e, g, h, _, _ = lf.following_breadcrumbs(X[inde], True, 'apriori', 'kmedoids', True)
#      40                     fr = fr + c - e
#      41                     frr = frr + g - h
#
# ~\Downloads\LionForests Journal\lionforests.py in following_breadcrumbs(self, instance, reduction, ar_algorithm, cl_algorithm, save_plots, instance_quorum, clusters, method)
#     329                     local_feature_names = list(items)
#     330             else:
# --> 331                 temp_rules = self.reduce_rules(rules, probabilities, instance_quorum, number_of_clusters, ar_algorithm, cl_algorithm, method, save_plots)
#     332                 if len(temp_rules[0]) != 0:
#     333                     rules = temp_rules[0]
#
# ~\Downloads\LionForests Journal\lionforests.py in reduce_rules(self, rules, probabilities, instance_quorum, number_of_clusters, ar_algorithm, cl_algorithm, method, save_plots)
#     454         if '1' in method:
#     455             # Step 1: Starting with Association rules
# --> 456             reduced_rules_t, reduced_probabilities_t = self.reduce_through_association_rules(reduced_rules, reduced_probabilities, instance_quorum, ar_algorithm, save_plots)
#     457             # In case AR reduce the paths to less than a quorum, we reset all the paths.
#     458             if np.array(reduced_probabilities_t).sum()/self.number_of_estimators > 0.5 and len(reduced_rules_t) >= instance_quorum:
#
# ~\Downloads\LionForests Journal\lionforests.py in reduce_through_association_rules(self, rules, probabilities, instance_quorum, ar_algorithm, save_plots)
#     549                 if save_plots:
#     550                     for i in range(0, k):
# --> 551                         for j in list(list(frequent_itemsets['antecedents'])[i]):
#     552                             feature_set.add(j)
#     553                 else:
#
# KeyboardInterrupt:

# %%
for i in results:
    print(i)
# Out:
# ['7', '100', 'sqrt', 'NoRed_Old', '_', '_', 10.00128600358963, 0.0, 0.0, 0.0]
# ['7', '100', 'sqrt', '123_Old', '_', '_', 7.231152970790863, 4.78, 26.27, 0.1]
# ['7', '100', 'log2', 'NoRed_Old', '_', '_', 10.070970542430878, 0.0, 0.0, 0.0]
# ['7', '100', 'log2', '123_Old', '_', '_', 7.746455664634705, 4.19, 24.9, 0.02]
# ['7', '100', '0.75', 'NoRed_Old', '_', '_', 8.627855756282806, 0.0, 0.0, 0.0]
# ['7', '100', '0.75', '123_Old', '_', '_', 759.4757613897324, 8.43, 32.68, 2.06]
# ['7', '100', 'None', 'NoRed_Old', '_', '_', 8.738904178142548, 0.0, 0.0, 0.0]
# ['7', '100', 'None', '123_Old', '_', '_', 272.78696763277054, 4.75, 34.15, 1.12]
# ['10', '100', 'sqrt', 'NoRed_Old', '_', '_', 12.970770132541656, 0.0, 0.0, 0.0]
# ['10', '100', 'sqrt', '123_Old', '_', '_', 27.833309004306795, 3.85, 27.95, 0.04]
# ['10', '100', 'log2', 'NoRed_Old', '_', '_', 14.498990025520325, 0.0, 0.0, 0.0]
# ['10', '100', 'log2', '123_Old', '_', '_', 10.362000272274017, 3.77, 25.6, 0.0]
# ['10', '100', '0.75', 'NoRed_Old', '_', '_', 11.581021025180817, 0.0, 0.0, 0.0]

# %%
10, 100, 0.75, 123_ολδ δεν το εχω κανει

# %%
for i in results:
    print(i)
# Out:
# ['7', '10', 'sqrt', 'NoRed_Old', '_', '_', 1.9661005997657777, 0.0, 0.0, 0.0]

# %%
for i in results:
    print(i)
# Out:
# ['1', '10', 'sqrt', 'NoRed_Old', '_', '_', 0.7374982237815857, 0.0, 0.0, 0.0]
# ['1', '10', 'sqrt', '123_Old', '_', '_', 0.34352524757385255, 2.98, 2.98, 2.37]
# ['1', '10', 'log2', 'NoRed_Old', '_', '_', 0.4569049692153931, 0.0, 0.0, 0.0]
# ['1', '10', 'log2', '123_Old', '_', '_', 0.3414418029785156, 2.98, 2.98, 1.67]
# ['1', '10', '0.75', 'NoRed_Old', '_', '_', 0.44762348413467407, 0.0, 0.0, 0.0]
# ['1', '10', '0.75', '123_Old', '_', '_', 0.40592183589935305, 0.49, 2.36, 0.49]
# ['1', '10', 'None', 'NoRed_Old', '_', '_', 0.40711336612701415, 0.0, 0.0, 0.0]
# ['1', '10', 'None', '123_Old', '_', '_', 0.38622174978256224, 0.0, 1.8, 0.0]
# ['1', '100', 'sqrt', 'NoRed_Old', '_', '_', 2.266574800014496, 0.0, 0.0, 0.0]
# ['1', '100', 'sqrt', '123_Old', '_', '_', 1.6553577232360839, 6.79, 31.47, 2.5]
# ['1', '100', 'log2', 'NoRed_Old', '_', '_', 2.3713323974609377, 0.0, 0.0, 0.0]
# ['1', '100', 'log2', '123_Old', '_', '_', 1.7719934535026551, 7.42, 32.06, 2.38]
# ['1', '100', '0.75', 'NoRed_Old', '_', '_', 1.707167043685913, 0.0, 0.0, 0.0]
# ['1', '100', '0.75', '123_Old', '_', '_', 1.3035369873046876, 0.45, 27.81, 0.45]
# ['1', '100', 'None', 'NoRed_Old', '_', '_', 1.7733677577972413, 0.0, 0.0, 0.0]
# ['1', '100', 'None', '123_Old', '_', '_', 1.3624646115303038, 0.0, 25.65, 0.0]
# ['1', '500', 'sqrt', 'NoRed_Old', '_', '_', 8.26366685628891, 0.0, 0.0, 0.0]
# ['1', '500', 'sqrt', '123_Old', '_', '_', 6.702879145145416, 18.41, 159.86, 4.29]
# ['1', '500', 'log2', 'NoRed_Old', '_', '_', 8.579281363487244, 0.0, 0.0, 0.0]
# ['1', '500', 'log2', '123_Old', '_', '_', 6.763026084899902, 19.4, 160.97, 3.57]
# ['1', '500', '0.75', 'NoRed_Old', '_', '_', 6.617137415409088, 0.0, 0.0, 0.0]
# ['1', '500', '0.75', '123_Old', '_', '_', 5.419650757312775, 0.0, 143.03, 0.0]
# ['1', '500', 'None', 'NoRed_Old', '_', '_', 8.621186583042144, 0.0, 0.0, 0.0]
# ['1', '500', 'None', '123_Old', '_', '_', 6.762887964248657, 0.0, 131.35, 0.0]
# ['5', '10', 'sqrt', 'NoRed_Old', '_', '_', 1.2821786546707152, 0.0, 0.0, 0.0]
# ['5', '10', 'sqrt', '123_Old', '_', '_', 30.226590979099274, 3.4, 2.22, 1.01]
# ['5', '10', 'log2', 'NoRed_Old', '_', '_', 1.530548689365387, 0.0, 0.0, 0.0]
# ['5', '10', 'log2', '123_Old', '_', '_', 23.947317583560945, 6.04, 2.49, 1.87]
# ['5', '10', '0.75', 'NoRed_Old', '_', '_', 1.0200077629089355, 0.0, 0.0, 0.0]
# ['5', '10', '0.75', '123_Old', '_', '_', 6.117214086055756, 2.2, 2.5, 0.52]
# ['5', '10', 'None', 'NoRed_Old', '_', '_', 0.922796151638031, 0.0, 0.0, 0.0]
# ['5', '10', 'None', '123_Old', '_', '_', 1.4290329384803773, 0.83, 2.67, 0.25]
# ['5', '100', 'sqrt', 'NoRed_Old', '_', '_', 7.350974290370941, 0.0, 0.0, 0.0]
# ['5', '100', 'sqrt', '123_Old', '_', '_', 5.639099636077881, 4.24, 24.88, 0.46]
# ['5', '100', 'log2', 'NoRed_Old', '_', '_', 7.709193394184113, 0.0, 0.0, 0.0]
# ['5', '100', 'log2', '123_Old', '_', '_', 6.109794461727143, 3.98, 25.39, 0.14]
# ['5', '100', '0.75', 'NoRed_Old', '_', '_', 6.057247982025147, 0.0, 0.0, 0.0]
# ['5', '100', '0.75', '123_Old', '_', '_', 5.077567212581634, 5.38, 29.87, 1.22]
# ['5', '100', 'None', 'NoRed_Old', '_', '_', 6.111597964763641, 0.0, 0.0, 0.0]
# ['5', '100', 'None', '123_Old', '_', '_', 5.027116765975952, 2.33, 31.41, 0.72]
# ['5', '500', 'sqrt', 'NoRed_Old', '_', '_', 31.195854153633118, 0.0, 0.0, 0.0]
# ['5', '500', 'sqrt', '123_Old', '_', '_', 27.016351165771486, 4.23, 125.21, 0.06]
# ['5', '500', 'log2', 'NoRed_Old', '_', '_', 34.45141400098801, 0.0, 0.0, 0.0]
# ['5', '500', 'log2', '123_Old', '_', '_', 27.358519592285155, 3.23, 126.7, 0.0]
# ['5', '500', '0.75', 'NoRed_Old', '_', '_', 29.489585740566255, 0.0, 0.0, 0.0]
# ['5', '500', '0.75', '123_Old', '_', '_', 24.362379283905028, 7.57, 151.53, 1.58]
# ['5', '500', 'None', 'NoRed_Old', '_', '_', 29.556838159561156, 0.0, 0.0, 0.0]
# ['5', '500', 'None', '123_Old', '_', '_', 22.992538294792176, 2.73, 156.04, 0.78]
